# %% [markdown]
# ## Distributed GPU Session Lab: replicate_model_fn
#
# In this lab, you will take the solution you created in Lab 03b and implement replicate_model_fn.
#
# As this function is being deprecated, do this lab last with time permitting.
#
# Helpful references:
# - https://www.tensorflow.org/api_docs/python/tf/contrib/estimator/replicate_model_fn

# %%
import tensorflow as tf
import time
import os
import numpy as np

# %%
# Convolution Block

def _conv(x,kernel,name,log=False):
    with tf.variable_scope(name):
        W = tf.get_variable(initializer=tf.truncated_normal(shape=kernel,stddev=0.01),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[kernel[3]]),name='b')
        conv = tf.nn.conv2d(x, W, strides=[1,1,1,1],padding='SAME')
        activation = tf.nn.relu(tf.add(conv,b))
        pool = tf.nn.max_pool(activation,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')
        if log==True:
            tf.summary.histogram("weights",W)
            tf.summary.histogram("biases",b)
            tf.summary.histogram("activations",activation)
        return pool

# Dense Block

def _dense(x,size_in,size_out,name,relu=False,log=False):
    with tf.variable_scope(name):
        flat = tf.reshape(x,[-1,size_in])
        W = tf.get_variable(initializer=tf.truncated_normal([size_in,size_out],stddev=0.1),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[size_out]),name='b')
        activation = tf.add(tf.matmul(flat,W),b)
        if relu==True:
            activation = tf.nn.relu(activation)
        if log==True:
            tf.summary.histogram("weights",W)
            tf.summary.histogram("biases",b)
            tf.summary.histogram("activations",activation)
        return activation

# %% [markdown]
# ### DO: Add TowerOptimizer to Optimizer

# %%
def cnnmodel_fn(features, labels, mode, params):
    
    #### 1 INFERNCE MODEL
    
    input_layer = tf.reshape(features, [-1, 32, 32, 3])
    conv1 = _conv(input_layer,kernel=[5,5,3,128],name='conv1',log=params['log'])
    conv2 = _conv(conv1,kernel=[5,5,128,128],name='conv2',log=params['log'])
    conv3 = _conv(conv2,kernel=[3,3,128,256],name='conv3',log=params['log'])
    conv4 = _conv(conv3,kernel=[3,3,256,512],name='conv4',log=params['log'])
    dense = _dense(conv4,size_in=2*2*512,size_out=params['dense_units'],
                   name='Dense',relu=True,log=params['log'])
    if mode==tf.estimator.ModeKeys.TRAIN:
        dense = tf.nn.dropout(dense,params['drop_out'])
    logits = _dense(dense,size_in=params['dense_units'],
                    size_out=10,name='Output',relu=False,log=params['log'])
        
    #### 2 CALCULATIONS AND METRICS
    
    predictions = {"classes": tf.argmax(input=logits,axis=1),
                   "logits": logits,
                   "probabilities": tf.nn.softmax(logits,name='softmax')}
    export_outputs = {'predictions': tf.estimator.export.PredictOutput(predictions)}
    if (mode==tf.estimator.ModeKeys.TRAIN or mode==tf.estimator.ModeKeys.EVAL):
        loss = tf.losses.sparse_softmax_cross_entropy(labels=labels,logits=logits)
        accuracy = tf.metrics.accuracy(
            labels=labels, predictions=tf.argmax(logits,axis=1))
        metrics = {'accuracy':accuracy}
        
    #### 3 MODE = PREDICT
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(
            mode=mode, predictions=predictions, export_outputs=export_outputs)

    #### 4 MODE = TRAIN

    if mode == tf.estimator.ModeKeys.TRAIN:
        learning_rate = tf.train.exponential_decay(
            params['learning_rate'],tf.train.get_global_step(),
            decay_steps=100000,decay_rate=0.96)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
        #
        # code here
        #
        train_op = optimizer.minimize(loss=loss,global_step=tf.train.get_global_step())
        tf.summary.scalar('learning_rate', learning_rate)
        tf.summary.scalar('accuracy',accuracy[1])
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss, train_op=train_op)
    
    #### 5 MODE = EVAL
    
    if mode == tf.estimator.ModeKeys.EVAL:
        return tf.estimator.EstimatorSpec(
            mode=mode,loss=loss,eval_metric_ops=metrics)

# %%
def parse_tfrecord(example):
    feature={'idx'     : tf.FixedLenFeature((), tf.int64),
             'label'   : tf.FixedLenFeature((), tf.int64),
             'image'   : tf.FixedLenFeature((), tf.string, default_value="")}
    parsed = tf.parse_single_example(example, feature)
    image = tf.decode_raw(parsed['image'],tf.float64)
    image = tf.cast(image,tf.float32)
    image = tf.reshape(image,[32,32,3])
    return image, parsed['label']

# %%
def image_scaling(x):
    return tf.image.per_image_standardization(x)

def distort(x):
    x = tf.image.resize_image_with_crop_or_pad(x, 40, 40)
    x = tf.random_crop(x, [32, 32, 3])
    x = tf.image.random_flip_left_right(x)
    return x

# %%
def dataset_input_fn(params):
    dataset = tf.data.TFRecordDataset(
        params['filenames'],num_parallel_reads=params['threads'])
    dataset = dataset.map(parse_tfrecord, num_parallel_calls=params['threads'])
    dataset = dataset.map(lambda x,y: (image_scaling(x),y),num_parallel_calls=params['threads'])
    if params['mode']==tf.estimator.ModeKeys.TRAIN:
        dataset = dataset.map(lambda x,y: (distort(x),y),num_parallel_calls=params['threads'])
        dataset = dataset.shuffle(buffer_size=params['shuffle_buff'])
    dataset = dataset.repeat()
    dataset = dataset.batch(params['batch'])
    dataset = dataset.prefetch(8*params['batch'])
    return dataset

# %%
model_params  = {'drop_out'      : 0.2,
                 'dense_units'   : 1024,
                 'learning_rate' : 1e-3,
                 'log'           : True,
                 'replicate'     : True
                }

# %%
config = tf.estimator.RunConfig(save_checkpoints_secs = 300,keep_checkpoint_max = 5)

# %% [markdown]
# ### DO: Wrap model_fn in replicate_model_fn

# %%
model_fn = # code here
# Out:
#   File "<ipython-input-1-cae347f5bbbd>", line 1
#     model_fn = # code here
#                           ^
# SyntaxError: invalid syntax

# %%
name = 'cnn_model/cnn_model_'
name = name + 'dense' + str(model_params['dense_units']) + '_'
name = name + 'drop' + str(model_params['drop_out']) + '_'
name = name + 'lr' + str(model_params['learning_rate']) + '_'
name = name + time.strftime("%Y%m%d%H%M%S")
model_dir  = os.path.join('./',name)

print(model_dir)
# Out:
# ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530

# %%
estimator = tf.estimator.Estimator(
    model_fn=model_fn,model_dir=model_dir,params=model_params,config=config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530', '_save_checkpoints_steps': None, '_master': '', '_save_summary_steps': 100, '_task_type': 'worker', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f732729f860>, '_log_step_count_steps': 100, '_num_worker_replicas': 1, '_evaluation_master': '', '_keep_checkpoint_max': 5, '_session_config': None, '_train_distribute': None, '_save_checkpoints_secs': 300, '_service': None, '_num_ps_replicas': 0, '_is_chief': True, '_task_id': 0, '_global_id_in_cluster': 0, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None}

# %%
train_files = !ls ./data/cifar10_data_00*.tfrecords
val_files   = !ls ./data/cifar10_data_01*.tfrecords

train_params = {'filenames'    : train_files,
                'mode'         : tf.estimator.ModeKeys.TRAIN,
                'threads'      : 16,
                'shuffle_buff' : 100000,
                'batch'        : 100
               }

eval_params  = {'filenames'    : val_files,
                'mode'         : tf.estimator.ModeKeys.EVAL,
                'threads'      : 8,
                'batch'        : 200
               }

train_spec = tf.estimator.TrainSpec(input_fn=lambda: dataset_input_fn(train_params),max_steps=200000)
eval_spec  = tf.estimator.EvalSpec(input_fn=lambda: dataset_input_fn(eval_params),steps=10,throttle_secs=60)

# %%
tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 60 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530/model.ckpt.
# INFO:tensorflow:loss = 2.3003664, step = 0
# INFO:tensorflow:global_step/sec: 46.9997
# INFO:tensorflow:loss = 2.302546, step = 100 (2.132 sec)
# INFO:tensorflow:global_step/sec: 64.9555
# INFO:tensorflow:loss = 2.2958536, step = 200 (1.540 sec)
# INFO:tensorflow:global_step/sec: 65.3998
# INFO:tensorflow:loss = 2.2967696, step = 300 (1.526 sec)
# INFO:tensorflow:global_step/sec: 69.9162
# INFO:tensorflow:loss = 2.2981205, step = 400 (1.433 sec)
# INFO:tensorflow:global_step/sec: 63.7525
# INFO:tensorflow:loss = 2.286377, step = 500 (1.571 sec)
# INFO:tensorflow:global_step/sec: 63.868
# INFO:tensorflow:loss = 2.2716293, step = 600 (1.563 sec)
# INFO:tensorflow:global_step/sec: 65.452
# INFO:tensorflow:loss = 2.2883277, step = 700 (1.526 sec)
# INFO:tensorflow:global_step/sec: 70.283
# INFO:tensorflow:loss = 2.2547479, step = 800 (1.425 sec)
# INFO:tensorflow:global_step/sec: 63.7536
# INFO:tensorflow:loss = 2.2419567, step = 900 (1.569 sec)
# INFO:tensorflow:global_step/sec: 63.6468
# INFO:tensorflow:loss = 2.2440357, step = 1000 (1.571 sec)
# INFO:tensorflow:global_step/sec: 66.7216
# INFO:tensorflow:loss = 2.2066112, step = 1100 (1.498 sec)
# INFO:tensorflow:global_step/sec: 67.2295
# INFO:tensorflow:loss = 2.1856089, step = 1200 (1.489 sec)
# INFO:tensorflow:global_step/sec: 65.4591
# INFO:tensorflow:loss = 2.1745667, step = 1300 (1.528 sec)
# INFO:tensorflow:global_step/sec: 63.7121
# INFO:tensorflow:loss = 2.10427, step = 1400 (1.570 sec)
# INFO:tensorflow:global_step/sec: 65.721
# INFO:tensorflow:loss = 2.1421762, step = 1500 (1.520 sec)
# INFO:tensorflow:global_step/sec: 65.0088
# INFO:tensorflow:loss = 2.08373, step = 1600 (1.540 sec)
# INFO:tensorflow:global_step/sec: 62.9712
# INFO:tensorflow:loss = 2.1307926, step = 1700 (1.587 sec)
# INFO:tensorflow:global_step/sec: 64.7462
# INFO:tensorflow:loss = 2.1399956, step = 1800 (1.545 sec)
# INFO:tensorflow:global_step/sec: 67.8543
# INFO:tensorflow:loss = 2.0069308, step = 1900 (1.472 sec)
# INFO:tensorflow:global_step/sec: 67.4778
# INFO:tensorflow:loss = 2.0490599, step = 2000 (1.484 sec)
# INFO:tensorflow:global_step/sec: 63.3042
# INFO:tensorflow:loss = 2.1145458, step = 2100 (1.579 sec)
# INFO:tensorflow:global_step/sec: 63.5714
# INFO:tensorflow:loss = 2.044464, step = 2200 (1.575 sec)
# INFO:tensorflow:global_step/sec: 70.6882
# INFO:tensorflow:loss = 1.970659, step = 2300 (1.411 sec)
# INFO:tensorflow:global_step/sec: 72.7317
# INFO:tensorflow:loss = 2.070082, step = 2400 (1.377 sec)
# INFO:tensorflow:global_step/sec: 64.6412
# INFO:tensorflow:loss = 1.9554412, step = 2500 (1.547 sec)
# INFO:tensorflow:global_step/sec: 64.8639
# INFO:tensorflow:loss = 1.9466181, step = 2600 (1.541 sec)
# INFO:tensorflow:global_step/sec: 65.007
# INFO:tensorflow:loss = 1.9337304, step = 2700 (1.537 sec)
# INFO:tensorflow:global_step/sec: 74.2218
# INFO:tensorflow:loss = 1.8897196, step = 2800 (1.347 sec)
# INFO:tensorflow:global_step/sec: 66.892
# INFO:tensorflow:loss = 1.8640549, step = 2900 (1.497 sec)
# INFO:tensorflow:global_step/sec: 65.5817
# INFO:tensorflow:loss = 2.0436068, step = 3000 (1.527 sec)
# INFO:tensorflow:global_step/sec: 64.448
# INFO:tensorflow:loss = 1.9710486, step = 3100 (1.550 sec)
# INFO:tensorflow:global_step/sec: 70.6561
# INFO:tensorflow:loss = 1.980741, step = 3200 (1.413 sec)
# INFO:tensorflow:global_step/sec: 70.9903
# INFO:tensorflow:loss = 1.8518821, step = 3300 (1.411 sec)
# INFO:tensorflow:global_step/sec: 65.0282
# INFO:tensorflow:loss = 1.9456692, step = 3400 (1.539 sec)
# INFO:tensorflow:global_step/sec: 65.657
# INFO:tensorflow:loss = 1.8271244, step = 3500 (1.523 sec)
# INFO:tensorflow:global_step/sec: 66.4571
# INFO:tensorflow:loss = 1.89338, step = 3600 (1.503 sec)
# INFO:tensorflow:Saving checkpoints for 3653 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.9822032.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-16-04:26:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530/model.ckpt-3653
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-16-04:26:35
# INFO:tensorflow:Saving dict for global step 3653: accuracy = 0.376, global_step = 3653, loss = 1.7717075
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530/model.ckpt-3653
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3654 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530/model.ckpt.
# INFO:tensorflow:loss = 1.9849417, step = 3653
# INFO:tensorflow:global_step/sec: 47.1238
# INFO:tensorflow:loss = 1.802122, step = 3753 (2.128 sec)
# INFO:tensorflow:global_step/sec: 66.9799
# INFO:tensorflow:loss = 1.7768571, step = 3853 (1.490 sec)
# INFO:tensorflow:global_step/sec: 65.6821
# INFO:tensorflow:loss = 1.8200855, step = 3953 (1.522 sec)
# INFO:tensorflow:global_step/sec: 69.8094
# INFO:tensorflow:loss = 1.9125419, step = 4053 (1.432 sec)
# INFO:tensorflow:global_step/sec: 65.4297
# INFO:tensorflow:loss = 1.9225146, step = 4153 (1.529 sec)
# INFO:tensorflow:global_step/sec: 65.6988
# INFO:tensorflow:loss = 1.8544655, step = 4253 (1.522 sec)
# INFO:tensorflow:global_step/sec: 66.7827
# INFO:tensorflow:loss = 1.7417204, step = 4353 (1.498 sec)
# INFO:tensorflow:global_step/sec: 68.9501
# INFO:tensorflow:loss = 1.7994992, step = 4453 (1.448 sec)
# INFO:tensorflow:global_step/sec: 64.8508
# INFO:tensorflow:loss = 1.8550897, step = 4553 (1.545 sec)
# INFO:tensorflow:global_step/sec: 65.59
# INFO:tensorflow:loss = 1.7616756, step = 4653 (1.524 sec)
# INFO:tensorflow:global_step/sec: 65.1651
# INFO:tensorflow:loss = 1.8688093, step = 4753 (1.534 sec)
# INFO:tensorflow:global_step/sec: 69.578
# INFO:tensorflow:loss = 1.851965, step = 4853 (1.436 sec)
# INFO:tensorflow:global_step/sec: 67.3904
# INFO:tensorflow:loss = 1.8958737, step = 4953 (1.486 sec)
# INFO:tensorflow:global_step/sec: 64.1815
# INFO:tensorflow:loss = 1.7156847, step = 5053 (1.557 sec)
# INFO:tensorflow:global_step/sec: 66.2851
# INFO:tensorflow:loss = 1.8133177, step = 5153 (1.509 sec)
# INFO:tensorflow:global_step/sec: 70.8415
# INFO:tensorflow:loss = 1.8546836, step = 5253 (1.411 sec)
# INFO:tensorflow:global_step/sec: 66.443
# INFO:tensorflow:loss = 1.8262333, step = 5353 (1.506 sec)
# INFO:tensorflow:global_step/sec: 66.1873
# INFO:tensorflow:loss = 1.8517123, step = 5453 (1.512 sec)
# INFO:tensorflow:global_step/sec: 65.3494
# INFO:tensorflow:loss = 1.6938734, step = 5553 (1.530 sec)
# INFO:tensorflow:global_step/sec: 68.7306
# INFO:tensorflow:loss = 1.7518202, step = 5653 (1.454 sec)
# INFO:tensorflow:global_step/sec: 65.0849
# INFO:tensorflow:loss = 1.6925714, step = 5753 (1.538 sec)
# INFO:tensorflow:global_step/sec: 66.1596
# INFO:tensorflow:loss = 1.8525517, step = 5853 (1.511 sec)
# INFO:tensorflow:global_step/sec: 65.1094
# INFO:tensorflow:loss = 1.8069737, step = 5953 (1.535 sec)
# INFO:tensorflow:global_step/sec: 68.5065
# INFO:tensorflow:loss = 1.831439, step = 6053 (1.461 sec)
# INFO:tensorflow:global_step/sec: 65.4197
# INFO:tensorflow:loss = 1.5955282, step = 6153 (1.529 sec)
# INFO:tensorflow:global_step/sec: 64.1003
# INFO:tensorflow:loss = 1.8828517, step = 6253 (1.559 sec)
# INFO:tensorflow:global_step/sec: 65.3195
# INFO:tensorflow:loss = 1.7910712, step = 6353 (1.534 sec)
# INFO:tensorflow:global_step/sec: 68.4575
# INFO:tensorflow:loss = 1.7447902, step = 6453 (1.456 sec)
# INFO:tensorflow:global_step/sec: 70.0344
# INFO:tensorflow:loss = 1.6804729, step = 6553 (1.430 sec)
# INFO:tensorflow:global_step/sec: 66.6982
# INFO:tensorflow:loss = 1.693553, step = 6653 (1.499 sec)
# INFO:tensorflow:global_step/sec: 67.3527
# INFO:tensorflow:loss = 1.6686705, step = 6753 (1.484 sec)
# INFO:tensorflow:global_step/sec: 67.2749
# INFO:tensorflow:loss = 1.7153217, step = 6853 (1.486 sec)
# INFO:tensorflow:global_step/sec: 71.6408
# INFO:tensorflow:loss = 1.7096219, step = 6953 (1.397 sec)
# INFO:tensorflow:global_step/sec: 65.3055
# INFO:tensorflow:loss = 1.7897573, step = 7053 (1.534 sec)
# INFO:tensorflow:global_step/sec: 67.2481
# INFO:tensorflow:loss = 1.7070355, step = 7153 (1.484 sec)
# INFO:tensorflow:global_step/sec: 67.0238
# INFO:tensorflow:loss = 1.6814169, step = 7253 (1.491 sec)
# INFO:tensorflow:Saving checkpoints for 7337 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.6335626.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-16-04:27:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530/model.ckpt-7337
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-16-04:27:38
# INFO:tensorflow:Saving dict for global step 7337: accuracy = 0.426, global_step = 7337, loss = 1.5325603
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716042530/model.ckpt-7337
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
