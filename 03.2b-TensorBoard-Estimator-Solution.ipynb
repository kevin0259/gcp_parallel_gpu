# %% [markdown]
# ## TensorBoard Session Lab: tf.estimator
#
# In this lab, you will take the solution you created in Lab 02b and implement TensorBoard summaries.
#
# #### Try: compare time for each step with vs. without Summary Histograms.
#
# Helpful references:
# - https://www.youtube.com/watch?reload=9&v=eBbEDRsCmv4

# %%
import tensorflow as tf
import time
import os
import numpy as np
# Out:
# /usr/lib/python3/dist-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Custom model function.
#
# 5 sections of the model function
#
# #### 1. INFERENCE MODEL
#
# Recommended architecture:
# - conv1: kernel = 5x5x128
# - conv2: kernel = 5x5x128
# - conv3: kernel = 3x3x256
# - conv4: kernel = 3x3x512
# - dense: hidden_units (tunable hyperparam)
#
# Use:
# - tf.nn - this will allow for metric collection later.
#
# #### 2. CALCULATIONS AND METRICS
#
# Implement:
# - Prediction dictionary {classes, logits, probabilities}.
# - Loss function: Cross Entropy.
# - Accuracy for both training and eval using tf.metrics.
#
# #### 3. MODE = PREDICT
#
# Implement:
# - EstimatorSpec for PREDICT.
#
# #### 4. MODE = TRAIN
#
# Implement:
# - Optimizer = Stochastic Gradient Descent.
# - EstimatorSpec for TRAIN.
# - Optional: Exponential Decay Learning Rate.
#
# #### 5. MODE = EVAL
#
# Implement:
# - EstimatorSpec for EVAL.

# %% [markdown]
# ### 1a - Add: Summary Histograms
#
# Implement the following for both _conv and _dense functions:
# - Summary Histogram for weights.
# - Summary Histogram for biases.
# - Summary Histogram for activations.
#
# Optional: Writing summaries can slow down training, and it is best to run with minimal summaries and only increase logging as needed for troubleshooting.  Optionally, implement logging flag to turn on/off summaries.

# %%
# Convolution Block

def _conv(x,kernel,name,log=False):
    with tf.variable_scope(name):
        W = tf.get_variable(initializer=tf.truncated_normal(shape=kernel,stddev=0.01),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[kernel[3]]),name='b')
        conv = tf.nn.conv2d(x, W, strides=[1,1,1,1],padding='SAME')
        activation = tf.nn.relu(tf.add(conv,b))
        pool = tf.nn.max_pool(activation,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')
        if log==True:
            tf.summary.histogram("weights",W)
            tf.summary.histogram("biases",b)
            tf.summary.histogram("activations",activation)
        return pool

# Dense Block

def _dense(x,size_in,size_out,name,relu=False,log=False):
    with tf.variable_scope(name):
        flat = tf.reshape(x,[-1,size_in])
        W = tf.get_variable(initializer=tf.truncated_normal([size_in,size_out],stddev=0.1),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[size_out]),name='b')
        activation = tf.add(tf.matmul(flat,W),b)
        if relu==True:
            activation = tf.nn.relu(activation)
        if log==True:
            tf.summary.histogram("weights",W)
            tf.summary.histogram("biases",b)
            tf.summary.histogram("activations",activation)
        return activation

# %% [markdown]
# ### 2 Add: Summary Scalars in 4 MODE = TRAIN section
#
# Implement in MODE=TRAIN:
# - Summary Scalar for Accuracy.
# - Summary Scalar for Learning Rate (if using exponential decay function).

# %% [markdown]
# ## 2a - Graph with bug

# %%
def cnnmodel_fn(features, labels, mode, params):
    
    #### 1 INFERNCE MODEL

   
    input_layer = tf.reshape(features, [-1, 32, 32, 3])
    conv1 = _conv(input_layer,kernel=[5,5,3,128],name='conv1',log=params['log'])
    conv2 = _conv(conv1,kernel=[5,5,128,128],name='conv2',log=params['log'])
    conv3 = _conv(conv2,kernel=[3,3,128,256],name='conv3',log=params['log'])
    conv4 = _conv(conv2,kernel=[5,5,128,256],name='conv4',log=params['log'])
    dense = _dense(conv2,size_in=2*2*2048,size_out=params['dense_units'],
                   name='Dense',relu=True,log=params['log'])
    if mode==tf.estimator.ModeKeys.TRAIN:
        dense = tf.nn.dropout(dense,params['drop_out'])
    logits = _dense(dense,size_in=params['dense_units'],
                    size_out=10,name='Output',relu=False,log=params['log'])
        
    #### 2 CALCULATIONS AND METRICS
    
    predictions = {"classes": tf.argmax(input=logits,axis=1),
                   "logits": logits,
                   "probabilities": tf.nn.softmax(logits,name='softmax')}
    export_outputs = {'predictions': tf.estimator.export.PredictOutput(predictions)}
    if (mode==tf.estimator.ModeKeys.TRAIN or mode==tf.estimator.ModeKeys.EVAL):
        loss = tf.losses.sparse_softmax_cross_entropy(labels=labels,logits=logits)
        accuracy = tf.metrics.accuracy(
            labels=labels, predictions=tf.argmax(logits,axis=1))
        metrics = {'accuracy':accuracy}
        
    #### 3 MODE = PREDICT
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(
            mode=mode, predictions=predictions, export_outputs=export_outputs)

    #### 4 MODE = TRAIN

    if mode == tf.estimator.ModeKeys.TRAIN:
        learning_rate = tf.train.exponential_decay(
            params['learning_rate'],tf.train.get_global_step(),
            decay_steps=100000,decay_rate=0.96)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss=loss,global_step=tf.train.get_global_step())
        tf.summary.scalar('learning_rate', learning_rate)
        tf.summary.scalar('accuracy',accuracy[1])
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss, train_op=train_op)
    
    #### 5 MODE = EVAL
    
    if mode == tf.estimator.ModeKeys.EVAL:
        return tf.estimator.EstimatorSpec(
            mode=mode,loss=loss,eval_metric_ops=metrics)

# %% [markdown]
# ## 2b - Fixed Graph

# %%
def cnnmodel_fn(features, labels, mode, params):
    
    #### 1 INFERNCE MODEL
    
    input_layer = tf.reshape(features, [-1, 32, 32, 3])
    conv1 = _conv(input_layer,kernel=[5,5,3,128],name='conv1',log=params['log'])
    conv2 = _conv(conv1,kernel=[5,5,128,128],name='conv2',log=params['log'])
    conv3 = _conv(conv2,kernel=[3,3,128,256],name='conv3',log=params['log'])
    conv4 = _conv(conv3,kernel=[3,3,256,512],name='conv4',log=params['log'])
    dense = _dense(conv4,size_in=2*2*512,size_out=params['dense_units'],
                   name='Dense',relu=True,log=params['log'])
    if mode==tf.estimator.ModeKeys.TRAIN:
        dense = tf.nn.dropout(dense,params['drop_out'])
    logits = _dense(dense,size_in=params['dense_units'],
                    size_out=10,name='Output',relu=False,log=params['log'])
        
    #### 2 CALCULATIONS AND METRICS
    
    predictions = {"classes": tf.argmax(input=logits,axis=1),
                   "logits": logits,
                   "probabilities": tf.nn.softmax(logits,name='softmax')}
    export_outputs = {'predictions': tf.estimator.export.PredictOutput(predictions)}
    if (mode==tf.estimator.ModeKeys.TRAIN or mode==tf.estimator.ModeKeys.EVAL):
        loss = tf.losses.sparse_softmax_cross_entropy(labels=labels,logits=logits)
        accuracy = tf.metrics.accuracy(
            labels=labels, predictions=tf.argmax(logits,axis=1))
        metrics = {'accuracy':accuracy}
        
    #### 3 MODE = PREDICT
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(
            mode=mode, predictions=predictions, export_outputs=export_outputs)

    #### 4 MODE = TRAIN

    if mode == tf.estimator.ModeKeys.TRAIN:
        learning_rate = tf.train.exponential_decay(
            params['learning_rate'],tf.train.get_global_step(),
            decay_steps=100000,decay_rate=0.96)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss=loss,global_step=tf.train.get_global_step())
        tf.summary.scalar('learning_rate', learning_rate)
        tf.summary.scalar('accuracy',accuracy[1])
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss, train_op=train_op)
    
    #### 5 MODE = EVAL
    
    if mode == tf.estimator.ModeKeys.EVAL:
        return tf.estimator.EstimatorSpec(
            mode=mode,loss=loss,eval_metric_ops=metrics)

# %% [markdown]
# ### 3a - Function to deserialize tfrecords files.
#
# Implement parse_tfrecord function:
# - Feature input: {idx: tf.int64, label: tf.int64, image: tf.string}
# - Return: image, label

# %%
def parse_tfrecord(example):
    feature={'idx'     : tf.FixedLenFeature((), tf.int64),
             'label'   : tf.FixedLenFeature((), tf.int64),
             'image'   : tf.FixedLenFeature((), tf.string, default_value="")}
    parsed = tf.parse_single_example(example, feature)
    image = tf.decode_raw(parsed['image'],tf.float64)
    image = tf.cast(image,tf.float32)
    image = tf.reshape(image,[32,32,3])
    return image, parsed['label']

# %% [markdown]
# No Change.

# %%
def image_scaling(x):
    return tf.image.per_image_standardization(x)

def distort(x):
    x = tf.image.resize_image_with_crop_or_pad(x, 40, 40)
    x = tf.random_crop(x, [32, 32, 3])
    x = tf.image.random_flip_left_right(x)
    return x

# %% [markdown]
# No Change.

# %%
def dataset_input_fn(params):
    dataset = tf.data.TFRecordDataset(
        params['filenames'],num_parallel_reads=params['threads'])
    dataset = dataset.map(parse_tfrecord, num_parallel_calls=params['threads'])
    dataset = dataset.map(lambda x,y: (image_scaling(x),y),num_parallel_calls=params['threads'])
    if params['mode']==tf.estimator.ModeKeys.TRAIN:
        dataset = dataset.map(lambda x,y: (distort(x),y),num_parallel_calls=params['threads'])
        dataset = dataset.shuffle(buffer_size=params['shuffle_buff'])
    dataset = dataset.repeat()
    dataset = dataset.batch(params['batch'])
    dataset = dataset.prefetch(8*params['batch'])
    return dataset

# %% [markdown]
# ### DO: Logging Switch Parameter
#
# Implement logging parameter to turn on/off histogram logging.

# %%
model_params  = {'drop_out'      : 0.2,
                 'dense_units'   : 1024,
                 'learning_rate' : 1e-3,
                 'log'           : True
                }

# %% [markdown]
# No Change.

# %%
config = tf.estimator.RunConfig(save_checkpoints_secs = 300,keep_checkpoint_max = 5)

# %%
#Set model_fn
model_fn = cnnmodel_fn

# %% [markdown]
# No Change.

# %%
name = 'cnn_model/cnn_model_'
name = name + 'dense' + str(model_params['dense_units']) + '_'
name = name + 'drop' + str(model_params['drop_out']) + '_'
name = name + 'lr' + str(model_params['learning_rate']) + '_'
name = name + time.strftime("%Y%m%d%H%M%S")
model_dir  = os.path.join('./',name)

print(model_dir)
# Out:
# ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348

# %% [markdown]
# No Change.

# %%
estimator = tf.estimator.Estimator(
    model_fn=model_fn,model_dir=model_dir,params=model_params,config=config)
# Out:
# INFO:tensorflow:Using config: {'_master': '', '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_session_config': None, '_num_worker_replicas': 1, '_train_distribute': None, '_log_step_count_steps': 100, '_save_checkpoints_secs': 300, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7feb6d235c18>, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_is_chief': True, '_task_id': 0, '_tf_random_seed': None, '_global_id_in_cluster': 0, '_model_dir': './cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348', '_device_fn': None, '_evaluation_master': '', '_service': None, '_task_type': 'worker'}

# %% [markdown]
# No Change.

# %%
train_files = !ls ./data/cifar10_data_00*.tfrecords
val_files   = !ls ./data/cifar10_data_01*.tfrecords

train_params = {'filenames'    : train_files,
                'mode'         : tf.estimator.ModeKeys.TRAIN,
                'threads'      : 16,
                'shuffle_buff' : 100000,
                'batch'        : 100
               }

eval_params  = {'filenames'    : val_files,
                'mode'         : tf.estimator.ModeKeys.EVAL,
                'threads'      : 8,
                'batch'        : 200
               }

# %% [markdown]
# No Change.

# %%
train_spec = tf.estimator.TrainSpec(input_fn=lambda: dataset_input_fn(train_params),max_steps=20000)
eval_spec  = tf.estimator.EvalSpec(input_fn=lambda: dataset_input_fn(eval_params),steps=10,throttle_secs=60)

# %% [markdown]
# No Change.

# %%
tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 60 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:loss = 2.3116095, step = 0
# INFO:tensorflow:global_step/sec: 51.0657
# INFO:tensorflow:loss = 2.3047068, step = 100 (1.960 sec)
# INFO:tensorflow:global_step/sec: 63.4933
# INFO:tensorflow:loss = 2.28834, step = 200 (1.574 sec)
# INFO:tensorflow:global_step/sec: 55.0056
# INFO:tensorflow:loss = 2.29004, step = 300 (1.819 sec)
# INFO:tensorflow:global_step/sec: 54.5691
# INFO:tensorflow:loss = 2.2888296, step = 400 (1.833 sec)
# INFO:tensorflow:global_step/sec: 63.5002
# INFO:tensorflow:loss = 2.2916415, step = 500 (1.574 sec)
# INFO:tensorflow:global_step/sec: 64.4325
# INFO:tensorflow:loss = 2.2718902, step = 600 (1.552 sec)
# INFO:tensorflow:global_step/sec: 64.7331
# INFO:tensorflow:loss = 2.2794645, step = 700 (1.545 sec)
# INFO:tensorflow:global_step/sec: 64.2627
# INFO:tensorflow:loss = 2.275316, step = 800 (1.556 sec)
# INFO:tensorflow:global_step/sec: 54.9588
# INFO:tensorflow:loss = 2.2545822, step = 900 (1.821 sec)
# INFO:tensorflow:global_step/sec: 62.7282
# INFO:tensorflow:loss = 2.2335706, step = 1000 (1.593 sec)
# INFO:tensorflow:global_step/sec: 64.2219
# INFO:tensorflow:loss = 2.2003374, step = 1100 (1.557 sec)
# INFO:tensorflow:global_step/sec: 64.5385
# INFO:tensorflow:loss = 2.2129564, step = 1200 (1.550 sec)
# INFO:tensorflow:global_step/sec: 64.0355
# INFO:tensorflow:loss = 2.157534, step = 1300 (1.562 sec)
# INFO:tensorflow:global_step/sec: 54.8656
# INFO:tensorflow:loss = 2.1270673, step = 1400 (1.824 sec)
# INFO:tensorflow:global_step/sec: 54.7475
# INFO:tensorflow:loss = 2.1375456, step = 1500 (1.825 sec)
# INFO:tensorflow:global_step/sec: 63.8154
# INFO:tensorflow:loss = 2.0756662, step = 1600 (1.567 sec)
# INFO:tensorflow:global_step/sec: 64.5937
# INFO:tensorflow:loss = 2.0702844, step = 1700 (1.548 sec)
# INFO:tensorflow:global_step/sec: 64.3224
# INFO:tensorflow:loss = 2.0437126, step = 1800 (1.555 sec)
# INFO:tensorflow:global_step/sec: 64.4309
# INFO:tensorflow:loss = 2.0019298, step = 1900 (1.552 sec)
# INFO:tensorflow:global_step/sec: 54.9281
# INFO:tensorflow:loss = 2.023603, step = 2000 (1.821 sec)
# INFO:tensorflow:global_step/sec: 63.925
# INFO:tensorflow:loss = 2.0869098, step = 2100 (1.564 sec)
# INFO:tensorflow:global_step/sec: 64.4948
# INFO:tensorflow:loss = 2.076364, step = 2200 (1.550 sec)
# INFO:tensorflow:global_step/sec: 64.5305
# INFO:tensorflow:loss = 2.0607884, step = 2300 (1.550 sec)
# INFO:tensorflow:global_step/sec: 63.8599
# INFO:tensorflow:loss = 1.9334903, step = 2400 (1.566 sec)
# INFO:tensorflow:global_step/sec: 54.7976
# INFO:tensorflow:loss = 1.9954933, step = 2500 (1.826 sec)
# INFO:tensorflow:global_step/sec: 56.6771
# INFO:tensorflow:loss = 2.0877213, step = 2600 (1.763 sec)
# INFO:tensorflow:global_step/sec: 64.383
# INFO:tensorflow:loss = 1.9172597, step = 2700 (1.553 sec)
# INFO:tensorflow:global_step/sec: 64.4145
# INFO:tensorflow:loss = 1.9992105, step = 2800 (1.552 sec)
# INFO:tensorflow:global_step/sec: 64.7206
# INFO:tensorflow:loss = 1.9556271, step = 2900 (1.545 sec)
# INFO:tensorflow:global_step/sec: 64.2542
# INFO:tensorflow:loss = 2.0017338, step = 3000 (1.556 sec)
# INFO:tensorflow:global_step/sec: 54.847
# INFO:tensorflow:loss = 1.9207693, step = 3100 (1.825 sec)
# INFO:tensorflow:Saving checkpoints for 3101 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.9207693.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-31-23:24:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-3101
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-31-23:24:54
# INFO:tensorflow:Saving dict for global step 3101: accuracy = 0.3525, global_step = 3101, loss = 1.8246342
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3101: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-3101
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-3101
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3101 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:loss = 1.9684509, step = 3101
# INFO:tensorflow:global_step/sec: 52.003
# INFO:tensorflow:loss = 1.9589611, step = 3201 (1.925 sec)
# INFO:tensorflow:global_step/sec: 62.8824
# INFO:tensorflow:loss = 1.88456, step = 3301 (1.589 sec)
# INFO:tensorflow:global_step/sec: 54.7697
# INFO:tensorflow:loss = 1.9374944, step = 3401 (1.830 sec)
# INFO:tensorflow:global_step/sec: 53.0008
# INFO:tensorflow:loss = 1.8564285, step = 3501 (1.884 sec)
# INFO:tensorflow:global_step/sec: 63.9329
# INFO:tensorflow:loss = 1.9210817, step = 3601 (1.563 sec)
# INFO:tensorflow:global_step/sec: 63.0819
# INFO:tensorflow:loss = 1.8103279, step = 3701 (1.586 sec)
# INFO:tensorflow:global_step/sec: 63.5044
# INFO:tensorflow:loss = 1.9004298, step = 3801 (1.574 sec)
# INFO:tensorflow:global_step/sec: 64.2436
# INFO:tensorflow:loss = 1.9880046, step = 3901 (1.556 sec)
# INFO:tensorflow:global_step/sec: 54.7823
# INFO:tensorflow:loss = 1.7727733, step = 4001 (1.827 sec)
# INFO:tensorflow:global_step/sec: 60.8584
# INFO:tensorflow:loss = 1.9115567, step = 4101 (1.642 sec)
# INFO:tensorflow:global_step/sec: 63.8149
# INFO:tensorflow:loss = 1.9411483, step = 4201 (1.567 sec)
# INFO:tensorflow:global_step/sec: 63.9004
# INFO:tensorflow:loss = 1.7834489, step = 4301 (1.565 sec)
# INFO:tensorflow:global_step/sec: 64.5803
# INFO:tensorflow:loss = 1.8944746, step = 4401 (1.549 sec)
# INFO:tensorflow:global_step/sec: 55.0008
# INFO:tensorflow:loss = 1.8398587, step = 4501 (1.819 sec)
# INFO:tensorflow:global_step/sec: 54.739
# INFO:tensorflow:loss = 1.8826435, step = 4601 (1.830 sec)
# INFO:tensorflow:global_step/sec: 63.2946
# INFO:tensorflow:loss = 1.8508058, step = 4701 (1.576 sec)
# INFO:tensorflow:global_step/sec: 62.9461
# INFO:tensorflow:loss = 1.6911218, step = 4801 (1.589 sec)
# INFO:tensorflow:global_step/sec: 63.959
# INFO:tensorflow:loss = 1.8594779, step = 4901 (1.564 sec)
# INFO:tensorflow:global_step/sec: 64.1372
# INFO:tensorflow:loss = 1.8332696, step = 5001 (1.559 sec)
# INFO:tensorflow:global_step/sec: 54.5333
# INFO:tensorflow:loss = 1.7087812, step = 5101 (1.835 sec)
# INFO:tensorflow:global_step/sec: 62.6551
# INFO:tensorflow:loss = 1.8258461, step = 5201 (1.595 sec)
# INFO:tensorflow:global_step/sec: 64.141
# INFO:tensorflow:loss = 1.8322678, step = 5301 (1.559 sec)
# INFO:tensorflow:global_step/sec: 63.8096
# INFO:tensorflow:loss = 1.7735231, step = 5401 (1.567 sec)
# INFO:tensorflow:global_step/sec: 64.4796
# INFO:tensorflow:loss = 1.8587699, step = 5501 (1.551 sec)
# INFO:tensorflow:global_step/sec: 54.8818
# INFO:tensorflow:loss = 1.9241393, step = 5601 (1.824 sec)
# INFO:tensorflow:global_step/sec: 55.045
# INFO:tensorflow:loss = 1.7672, step = 5701 (1.815 sec)
# INFO:tensorflow:global_step/sec: 63.6519
# INFO:tensorflow:loss = 1.7479738, step = 5801 (1.571 sec)
# INFO:tensorflow:global_step/sec: 63.3524
# INFO:tensorflow:loss = 1.7620883, step = 5901 (1.578 sec)
# INFO:tensorflow:global_step/sec: 64.3571
# INFO:tensorflow:loss = 1.6972933, step = 6001 (1.554 sec)
# INFO:tensorflow:global_step/sec: 64.0959
# INFO:tensorflow:loss = 1.7593416, step = 6101 (1.560 sec)
# INFO:tensorflow:global_step/sec: 54.6249
# INFO:tensorflow:loss = 1.7401134, step = 6201 (1.832 sec)
# INFO:tensorflow:global_step/sec: 63.7879
# INFO:tensorflow:loss = 1.8369594, step = 6301 (1.567 sec)
# INFO:tensorflow:global_step/sec: 64.3257
# INFO:tensorflow:loss = 1.6894677, step = 6401 (1.555 sec)
# INFO:tensorflow:global_step/sec: 63.6047
# INFO:tensorflow:loss = 2.0159729, step = 6501 (1.573 sec)
# INFO:tensorflow:Saving checkpoints for 6533 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.8371272.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-31-23:25:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-6533
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-31-23:25:55
# INFO:tensorflow:Saving dict for global step 6533: accuracy = 0.438, global_step = 6533, loss = 1.5716894
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6533: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-6533
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-6533
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6533 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:loss = 1.7670932, step = 6533
# INFO:tensorflow:global_step/sec: 51.6338
# INFO:tensorflow:loss = 1.7510163, step = 6633 (1.938 sec)
# INFO:tensorflow:global_step/sec: 63.1751
# INFO:tensorflow:loss = 1.6827816, step = 6733 (1.582 sec)
# INFO:tensorflow:global_step/sec: 54.4778
# INFO:tensorflow:loss = 1.7420628, step = 6833 (1.837 sec)
# INFO:tensorflow:global_step/sec: 54.2057
# INFO:tensorflow:loss = 1.7123978, step = 6933 (1.845 sec)
# INFO:tensorflow:global_step/sec: 63.5915
# INFO:tensorflow:loss = 1.6066518, step = 7033 (1.571 sec)
# INFO:tensorflow:global_step/sec: 63.9897
# INFO:tensorflow:loss = 1.7227492, step = 7133 (1.563 sec)
# INFO:tensorflow:global_step/sec: 63.6893
# INFO:tensorflow:loss = 1.806149, step = 7233 (1.570 sec)
# INFO:tensorflow:global_step/sec: 63.4457
# INFO:tensorflow:loss = 1.7108018, step = 7333 (1.577 sec)
# INFO:tensorflow:global_step/sec: 54.3086
# INFO:tensorflow:loss = 1.8364542, step = 7433 (1.842 sec)
# INFO:tensorflow:global_step/sec: 63.3202
# INFO:tensorflow:loss = 1.6502515, step = 7533 (1.578 sec)
# INFO:tensorflow:global_step/sec: 63.3909
# INFO:tensorflow:loss = 1.721101, step = 7633 (1.578 sec)
# INFO:tensorflow:global_step/sec: 63.5586
# INFO:tensorflow:loss = 1.5494742, step = 7733 (1.574 sec)
# INFO:tensorflow:global_step/sec: 64.0206
# INFO:tensorflow:loss = 1.7602794, step = 7833 (1.561 sec)
# INFO:tensorflow:global_step/sec: 54.6881
# INFO:tensorflow:loss = 1.7260649, step = 7933 (1.831 sec)
# INFO:tensorflow:global_step/sec: 54.5278
# INFO:tensorflow:loss = 1.6051651, step = 8033 (1.833 sec)
# INFO:tensorflow:global_step/sec: 64.1705
# INFO:tensorflow:loss = 1.5377517, step = 8133 (1.557 sec)
# INFO:tensorflow:global_step/sec: 63.9479
# INFO:tensorflow:loss = 1.6625706, step = 8233 (1.564 sec)
# INFO:tensorflow:global_step/sec: 63.5783
# INFO:tensorflow:loss = 1.5506964, step = 8333 (1.572 sec)
# INFO:tensorflow:global_step/sec: 64.019
# INFO:tensorflow:loss = 1.6875888, step = 8433 (1.562 sec)
# INFO:tensorflow:global_step/sec: 54.5292
# INFO:tensorflow:loss = 1.604338, step = 8533 (1.835 sec)
# INFO:tensorflow:global_step/sec: 63.588
# INFO:tensorflow:loss = 1.7565652, step = 8633 (1.572 sec)
# INFO:tensorflow:global_step/sec: 64.1766
# INFO:tensorflow:loss = 1.6495632, step = 8733 (1.558 sec)
# INFO:tensorflow:global_step/sec: 64.5565
# INFO:tensorflow:loss = 1.8468881, step = 8833 (1.549 sec)
# INFO:tensorflow:global_step/sec: 63.7887
# INFO:tensorflow:loss = 1.6956984, step = 8933 (1.568 sec)
# INFO:tensorflow:global_step/sec: 54.6757
# INFO:tensorflow:loss = 1.6199341, step = 9033 (1.830 sec)
# INFO:tensorflow:global_step/sec: 56.654
# INFO:tensorflow:loss = 1.4814153, step = 9133 (1.764 sec)
# INFO:tensorflow:global_step/sec: 62.4194
# INFO:tensorflow:loss = 1.6534663, step = 9233 (1.602 sec)
# INFO:tensorflow:global_step/sec: 63.566
# INFO:tensorflow:loss = 1.5985043, step = 9333 (1.573 sec)
# INFO:tensorflow:global_step/sec: 64.1046
# INFO:tensorflow:loss = 1.5327649, step = 9433 (1.560 sec)
# INFO:tensorflow:global_step/sec: 64.0021
# INFO:tensorflow:loss = 1.480555, step = 9533 (1.562 sec)
# INFO:tensorflow:global_step/sec: 54.4992
# INFO:tensorflow:loss = 1.7635094, step = 9633 (1.836 sec)
# INFO:tensorflow:global_step/sec: 63.703
# INFO:tensorflow:loss = 1.6899376, step = 9733 (1.569 sec)
# INFO:tensorflow:global_step/sec: 63.8011
# INFO:tensorflow:loss = 1.7223725, step = 9833 (1.567 sec)
# INFO:tensorflow:global_step/sec: 62.8228
# INFO:tensorflow:loss = 1.617444, step = 9933 (1.592 sec)
# INFO:tensorflow:Saving checkpoints for 9981 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.7208763.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-31-23:26:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-9981
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-31-23:26:56
# INFO:tensorflow:Saving dict for global step 9981: accuracy = 0.485, global_step = 9981, loss = 1.4359215
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9981: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-9981
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-9981
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9981 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:loss = 1.5119072, step = 9981
# INFO:tensorflow:global_step/sec: 51.3825
# INFO:tensorflow:loss = 1.7571766, step = 10081 (1.948 sec)
# INFO:tensorflow:global_step/sec: 61.2067
# INFO:tensorflow:loss = 1.6911908, step = 10181 (1.633 sec)
# INFO:tensorflow:global_step/sec: 54.6555
# INFO:tensorflow:loss = 1.5520215, step = 10281 (1.831 sec)
# INFO:tensorflow:global_step/sec: 54.3295
# INFO:tensorflow:loss = 1.7441462, step = 10381 (1.840 sec)
# INFO:tensorflow:global_step/sec: 62.9827
# INFO:tensorflow:loss = 1.6690637, step = 10481 (1.587 sec)
# INFO:tensorflow:global_step/sec: 63.8744
# INFO:tensorflow:loss = 1.5155905, step = 10581 (1.566 sec)
# INFO:tensorflow:global_step/sec: 64.1353
# INFO:tensorflow:loss = 1.7330688, step = 10681 (1.559 sec)
# INFO:tensorflow:global_step/sec: 64.155
# INFO:tensorflow:loss = 1.5531578, step = 10781 (1.558 sec)
# INFO:tensorflow:global_step/sec: 54.345
# INFO:tensorflow:loss = 1.4878923, step = 10881 (1.841 sec)
# INFO:tensorflow:global_step/sec: 61.7819
# INFO:tensorflow:loss = 1.4701368, step = 10981 (1.618 sec)
# INFO:tensorflow:global_step/sec: 64.2386
# INFO:tensorflow:loss = 1.4180487, step = 11081 (1.557 sec)
# INFO:tensorflow:global_step/sec: 63.7868
# INFO:tensorflow:loss = 1.4935081, step = 11181 (1.568 sec)
# INFO:tensorflow:global_step/sec: 64.0814
# INFO:tensorflow:loss = 1.4263295, step = 11281 (1.560 sec)
# INFO:tensorflow:global_step/sec: 54.4397
# INFO:tensorflow:loss = 1.5801408, step = 11381 (1.838 sec)
# INFO:tensorflow:global_step/sec: 54.4649
# INFO:tensorflow:loss = 1.4186599, step = 11481 (1.835 sec)
# INFO:tensorflow:global_step/sec: 63.2815
# INFO:tensorflow:loss = 1.4421811, step = 11581 (1.580 sec)
# INFO:tensorflow:global_step/sec: 64.0444
# INFO:tensorflow:loss = 1.6099348, step = 11681 (1.561 sec)
# INFO:tensorflow:global_step/sec: 63.6163
# INFO:tensorflow:loss = 1.5810515, step = 11781 (1.572 sec)
# INFO:tensorflow:global_step/sec: 63.6313
# INFO:tensorflow:loss = 1.6434014, step = 11881 (1.571 sec)
# INFO:tensorflow:global_step/sec: 54.1715
# INFO:tensorflow:loss = 1.5734892, step = 11981 (1.847 sec)
# INFO:tensorflow:global_step/sec: 63.2681
# INFO:tensorflow:loss = 1.511953, step = 12081 (1.580 sec)
# INFO:tensorflow:global_step/sec: 64.2679
# INFO:tensorflow:loss = 1.5534921, step = 12181 (1.556 sec)
# INFO:tensorflow:global_step/sec: 63.4668
# INFO:tensorflow:loss = 1.5282674, step = 12281 (1.576 sec)
# INFO:tensorflow:global_step/sec: 63.8386
# INFO:tensorflow:loss = 1.4283519, step = 12381 (1.566 sec)
# INFO:tensorflow:global_step/sec: 54.4728
# INFO:tensorflow:loss = 1.5257597, step = 12481 (1.837 sec)
# INFO:tensorflow:global_step/sec: 54.7628
# INFO:tensorflow:loss = 1.5000126, step = 12581 (1.825 sec)
# INFO:tensorflow:global_step/sec: 64.0864
# INFO:tensorflow:loss = 1.3526509, step = 12681 (1.560 sec)
# INFO:tensorflow:global_step/sec: 64.0301
# INFO:tensorflow:loss = 1.4747124, step = 12781 (1.562 sec)
# INFO:tensorflow:global_step/sec: 63.7254
# INFO:tensorflow:loss = 1.4932376, step = 12881 (1.569 sec)
# INFO:tensorflow:global_step/sec: 63.9234
# INFO:tensorflow:loss = 1.6552085, step = 12981 (1.565 sec)
# INFO:tensorflow:global_step/sec: 54.4098
# INFO:tensorflow:loss = 1.6414105, step = 13081 (1.838 sec)
# INFO:tensorflow:global_step/sec: 63.4595
# INFO:tensorflow:loss = 1.5197526, step = 13181 (1.575 sec)
# INFO:tensorflow:global_step/sec: 63.1366
# INFO:tensorflow:loss = 1.4987482, step = 13281 (1.584 sec)
# INFO:tensorflow:global_step/sec: 64.0038
# INFO:tensorflow:loss = 1.5532956, step = 13381 (1.562 sec)
# INFO:tensorflow:Saving checkpoints for 13410 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.438108.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-31-23:27:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-13410
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-31-23:27:57
# INFO:tensorflow:Saving dict for global step 13410: accuracy = 0.5395, global_step = 13410, loss = 1.3325936
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13410: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-13410
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-13410
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13410 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:loss = 1.4346476, step = 13410
# INFO:tensorflow:global_step/sec: 51.5216
# INFO:tensorflow:loss = 1.5229137, step = 13510 (1.943 sec)
# INFO:tensorflow:global_step/sec: 63.0454
# INFO:tensorflow:loss = 1.6349771, step = 13610 (1.585 sec)
# INFO:tensorflow:global_step/sec: 54.5076
# INFO:tensorflow:loss = 1.3382295, step = 13710 (1.836 sec)
# INFO:tensorflow:global_step/sec: 54.4467
# INFO:tensorflow:loss = 1.6040716, step = 13810 (1.840 sec)
# INFO:tensorflow:global_step/sec: 63.2312
# INFO:tensorflow:loss = 1.4980298, step = 13910 (1.577 sec)
# INFO:tensorflow:global_step/sec: 64.0133
# INFO:tensorflow:loss = 1.4342549, step = 14010 (1.562 sec)
# INFO:tensorflow:global_step/sec: 64.2543
# INFO:tensorflow:loss = 1.5938356, step = 14110 (1.557 sec)
# INFO:tensorflow:global_step/sec: 63.7339
# INFO:tensorflow:loss = 1.4777735, step = 14210 (1.569 sec)
# INFO:tensorflow:global_step/sec: 54.6069
# INFO:tensorflow:loss = 1.5158031, step = 14310 (1.832 sec)
# INFO:tensorflow:global_step/sec: 62.5483
# INFO:tensorflow:loss = 1.3604333, step = 14410 (1.598 sec)
# INFO:tensorflow:global_step/sec: 64.182
# INFO:tensorflow:loss = 1.3731838, step = 14510 (1.558 sec)
# INFO:tensorflow:global_step/sec: 64.4312
# INFO:tensorflow:loss = 1.6413636, step = 14610 (1.552 sec)
# INFO:tensorflow:global_step/sec: 63.869
# INFO:tensorflow:loss = 1.6131138, step = 14710 (1.566 sec)
# INFO:tensorflow:global_step/sec: 54.5997
# INFO:tensorflow:loss = 1.5188216, step = 14810 (1.832 sec)
# INFO:tensorflow:global_step/sec: 54.3938
# INFO:tensorflow:loss = 1.5204431, step = 14910 (1.838 sec)
# INFO:tensorflow:global_step/sec: 63.9731
# INFO:tensorflow:loss = 1.4041365, step = 15010 (1.563 sec)
# INFO:tensorflow:global_step/sec: 64.188
# INFO:tensorflow:loss = 1.597047, step = 15110 (1.558 sec)
# INFO:tensorflow:global_step/sec: 64.0059
# INFO:tensorflow:loss = 1.6399901, step = 15210 (1.563 sec)
# INFO:tensorflow:global_step/sec: 64.0386
# INFO:tensorflow:loss = 1.5947009, step = 15310 (1.561 sec)
# INFO:tensorflow:global_step/sec: 54.1174
# INFO:tensorflow:loss = 1.3214967, step = 15410 (1.849 sec)
# INFO:tensorflow:global_step/sec: 63.5247
# INFO:tensorflow:loss = 1.4118096, step = 15510 (1.573 sec)
# INFO:tensorflow:global_step/sec: 64.116
# INFO:tensorflow:loss = 1.4084972, step = 15610 (1.560 sec)
# INFO:tensorflow:global_step/sec: 63.8862
# INFO:tensorflow:loss = 1.6967235, step = 15710 (1.566 sec)
# INFO:tensorflow:global_step/sec: 63.7006
# INFO:tensorflow:loss = 1.5233557, step = 15810 (1.569 sec)
# INFO:tensorflow:global_step/sec: 54.415
# INFO:tensorflow:loss = 1.445396, step = 15910 (1.839 sec)
# INFO:tensorflow:global_step/sec: 56.5595
# INFO:tensorflow:loss = 1.5745267, step = 16010 (1.767 sec)
# INFO:tensorflow:global_step/sec: 63.8906
# INFO:tensorflow:loss = 1.4418328, step = 16110 (1.565 sec)
# INFO:tensorflow:global_step/sec: 63.4307
# INFO:tensorflow:loss = 1.2996397, step = 16210 (1.576 sec)
# INFO:tensorflow:global_step/sec: 64.204
# INFO:tensorflow:loss = 1.5006734, step = 16310 (1.558 sec)
# INFO:tensorflow:global_step/sec: 63.6507
# INFO:tensorflow:loss = 1.4011418, step = 16410 (1.571 sec)
# INFO:tensorflow:global_step/sec: 54.1267
# INFO:tensorflow:loss = 1.4565259, step = 16510 (1.852 sec)
# INFO:tensorflow:global_step/sec: 63.0544
# INFO:tensorflow:loss = 1.3336223, step = 16610 (1.582 sec)
# INFO:tensorflow:global_step/sec: 64.0318
# INFO:tensorflow:loss = 1.2919976, step = 16710 (1.562 sec)
# INFO:tensorflow:global_step/sec: 64.4105
# INFO:tensorflow:loss = 1.6765687, step = 16810 (1.552 sec)
# INFO:tensorflow:Saving checkpoints for 16861 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.300904.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-31-23:28:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-16861
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-31-23:28:58
# INFO:tensorflow:Saving dict for global step 16861: accuracy = 0.586, global_step = 16861, loss = 1.2154354
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16861: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-16861
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-16861
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 16861 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:loss = 1.5541309, step = 16861
# INFO:tensorflow:global_step/sec: 51.404
# INFO:tensorflow:loss = 1.2583499, step = 16961 (1.948 sec)
# INFO:tensorflow:global_step/sec: 63.2661
# INFO:tensorflow:loss = 1.2747589, step = 17061 (1.579 sec)
# INFO:tensorflow:global_step/sec: 54.6749
# INFO:tensorflow:loss = 1.3804083, step = 17161 (1.830 sec)
# INFO:tensorflow:global_step/sec: 54.3725
# INFO:tensorflow:loss = 1.3504324, step = 17261 (1.840 sec)
# INFO:tensorflow:global_step/sec: 63.5329
# INFO:tensorflow:loss = 1.4722033, step = 17361 (1.573 sec)
# INFO:tensorflow:global_step/sec: 63.9647
# INFO:tensorflow:loss = 1.4430892, step = 17461 (1.563 sec)
# INFO:tensorflow:global_step/sec: 64.1746
# INFO:tensorflow:loss = 1.3809282, step = 17561 (1.558 sec)
# INFO:tensorflow:global_step/sec: 63.8061
# INFO:tensorflow:loss = 1.6009994, step = 17661 (1.567 sec)
# INFO:tensorflow:global_step/sec: 54.412
# INFO:tensorflow:loss = 1.4492623, step = 17761 (1.839 sec)
# INFO:tensorflow:global_step/sec: 62.4454
# INFO:tensorflow:loss = 1.4420478, step = 17861 (1.601 sec)
# INFO:tensorflow:global_step/sec: 63.9256
# INFO:tensorflow:loss = 1.3937819, step = 17961 (1.564 sec)
# INFO:tensorflow:global_step/sec: 63.4685
# INFO:tensorflow:loss = 1.4419625, step = 18061 (1.576 sec)
# INFO:tensorflow:global_step/sec: 64.3882
# INFO:tensorflow:loss = 1.5203338, step = 18161 (1.554 sec)
# INFO:tensorflow:global_step/sec: 54.708
# INFO:tensorflow:loss = 1.3978385, step = 18261 (1.829 sec)
# INFO:tensorflow:global_step/sec: 54.5076
# INFO:tensorflow:loss = 1.5933651, step = 18361 (1.834 sec)
# INFO:tensorflow:global_step/sec: 63.2248
# INFO:tensorflow:loss = 1.3540351, step = 18461 (1.581 sec)
# INFO:tensorflow:global_step/sec: 64.1421
# INFO:tensorflow:loss = 1.108459, step = 18561 (1.559 sec)
# INFO:tensorflow:global_step/sec: 64.1373
# INFO:tensorflow:loss = 1.2666981, step = 18661 (1.559 sec)
# INFO:tensorflow:global_step/sec: 63.4363
# INFO:tensorflow:loss = 1.3893218, step = 18761 (1.577 sec)
# INFO:tensorflow:global_step/sec: 54.1789
# INFO:tensorflow:loss = 1.4442761, step = 18861 (1.849 sec)
# INFO:tensorflow:global_step/sec: 63.498
# INFO:tensorflow:loss = 1.4753553, step = 18961 (1.571 sec)
# INFO:tensorflow:global_step/sec: 63.9964
# INFO:tensorflow:loss = 1.3129522, step = 19061 (1.563 sec)
# INFO:tensorflow:global_step/sec: 63.5327
# INFO:tensorflow:loss = 1.1461682, step = 19161 (1.574 sec)
# INFO:tensorflow:global_step/sec: 64.2809
# INFO:tensorflow:loss = 1.3599528, step = 19261 (1.556 sec)
# INFO:tensorflow:global_step/sec: 53.9615
# INFO:tensorflow:loss = 1.3995956, step = 19361 (1.856 sec)
# INFO:tensorflow:global_step/sec: 56.5976
# INFO:tensorflow:loss = 1.2193894, step = 19461 (1.763 sec)
# INFO:tensorflow:global_step/sec: 64.1008
# INFO:tensorflow:loss = 1.3924665, step = 19561 (1.560 sec)
# INFO:tensorflow:global_step/sec: 64.1096
# INFO:tensorflow:loss = 1.2686975, step = 19661 (1.560 sec)
# INFO:tensorflow:global_step/sec: 63.844
# INFO:tensorflow:loss = 1.3367479, step = 19761 (1.566 sec)
# INFO:tensorflow:global_step/sec: 63.4773
# INFO:tensorflow:loss = 1.2095848, step = 19861 (1.575 sec)
# INFO:tensorflow:global_step/sec: 54.2668
# INFO:tensorflow:loss = 1.3267074, step = 19961 (1.844 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.3517025.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-31-23:29:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-31-23:29:55
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.6155, global_step = 20000, loss = 1.1266121
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180731232348/model.ckpt-20000
# ({'accuracy': 0.6155, 'global_step': 20000, 'loss': 1.1266121}, [])
