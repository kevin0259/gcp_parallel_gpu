# %% [markdown]
# ## TensorBoard Session Lab: tf.estimator
#
# In this lab, you will take the solution you created in Lab 02b and implement TensorBoard summaries.
#
# #### Try: compare time for each step with vs. without Summary Histograms.
#
# Helpful references:
# - https://www.youtube.com/watch?reload=9&v=eBbEDRsCmv4

# %%
import tensorflow as tf
import time
import os
import numpy as np
# Out:
# /home/jasmeetbhatia/anaconda3/envs/tf19gpu/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### 1a - Add: Summary Histograms
#
# Implement the following for both _conv and _dense functions:
# - Summary Histogram for weights.
# - Summary Histogram for biases.
# - Summary Histogram for activations.
#
# Optional: Writing summaries can slow down training, and it is best to run with minimal summaries and only increase logging as needed for troubleshooting.  Optionally, implement logging flag to turn on/off summaries.

# %%
# Convolution Block

def _conv(x,kernel,name,log=False):
    with tf.variable_scope(name):
        W = tf.get_variable(initializer=tf.truncated_normal(shape=kernel,stddev=0.01),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[kernel[3]]),name='b')
        conv = tf.nn.conv2d(x, W, strides=[1,1,1,1],padding='SAME')
        activation = tf.nn.relu(tf.add(conv,b))
        pool = tf.nn.max_pool(activation,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')
        #if log==True:
            #
            # code here
            #
        return pool

# Dense Block

def _dense(x,size_in,size_out,name,relu=False,log=False):
    with tf.variable_scope(name):
        flat = tf.reshape(x,[-1,size_in])
        W = tf.get_variable(initializer=tf.truncated_normal([size_in,size_out],stddev=0.1),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[size_out]),name='b')
        activation = tf.add(tf.matmul(flat,W),b)
        if relu==True:
            activation = tf.nn.relu(activation)
        #if log==True:
            #
            # code here
            #
        return activation

# %% [markdown]
# ### 2 Add: Summary Scalars in 4 MODE = TRAIN section
#
# Implement in MODE=TRAIN:
# - Summary Scalar for Accuracy.
# - Summary Scalar for Learning Rate (if using exponential decay function).

# %%
def cnnmodel_fn(features, labels, mode, params):
    
    #### 1 INFERNCE MODEL
    
    input_layer = tf.reshape(features, [-1, 32, 32, 3])
    conv1 = _conv(input_layer,kernel=[5,5,3,128],name='conv1',log=params['log'])
    conv2 = _conv(conv1,kernel=[5,5,128,128],name='conv2',log=params['log'])
    conv3 = _conv(conv2,kernel=[3,3,128,256],name='conv3',log=params['log'])
    conv4 = _conv(conv3,kernel=[3,3,256,512],name='conv4',log=params['log'])
    dense = _dense(conv4,size_in=2*2*512,size_out=params['dense_units'],
                   name='Dense',relu=True,log=params['log'])
    if mode==tf.estimator.ModeKeys.TRAIN:
        dense = tf.nn.dropout(dense,params['drop_out'])
    logits = _dense(dense,size_in=params['dense_units'],
                    size_out=10,name='Output',relu=False,log=params['log'])
        
    #### 2 CALCULATIONS AND METRICS
    
    predictions = {"classes": tf.argmax(input=logits,axis=1),
                   "logits": logits,
                   "probabilities": tf.nn.softmax(logits,name='softmax')}
    export_outputs = {'predictions': tf.estimator.export.PredictOutput(predictions)}
    if (mode==tf.estimator.ModeKeys.TRAIN or mode==tf.estimator.ModeKeys.EVAL):
        loss = tf.losses.sparse_softmax_cross_entropy(labels=labels,logits=logits)
        accuracy = tf.metrics.accuracy(
            labels=labels, predictions=tf.argmax(logits,axis=1))
        metrics = {'accuracy':accuracy}
        
    #### 3 MODE = PREDICT
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(
            mode=mode, predictions=predictions, export_outputs=export_outputs)

    #### 4 MODE = TRAIN

    if mode == tf.estimator.ModeKeys.TRAIN:
        learning_rate = tf.train.exponential_decay(
            params['learning_rate'],tf.train.get_global_step(),
            decay_steps=100000,decay_rate=0.96)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss=loss,global_step=tf.train.get_global_step())
        #
        # code here
        #
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss, train_op=train_op)
    
    #### 5 MODE = EVAL
    
    if mode == tf.estimator.ModeKeys.EVAL:
        return tf.estimator.EstimatorSpec(
            mode=mode,loss=loss,eval_metric_ops=metrics)

# %% [markdown]
# No Change.

# %%
def parse_tfrecord(example):
    feature={'idx'     : tf.FixedLenFeature((), tf.int64),
             'label'   : tf.FixedLenFeature((), tf.int64),
             'image'   : tf.FixedLenFeature((), tf.string, default_value="")}
    parsed = tf.parse_single_example(example, feature)
    image = tf.decode_raw(parsed['image'],tf.float64)
    image = tf.cast(image,tf.float32)
    image = tf.reshape(image,[32,32,3])
    return image, parsed['label']

# %% [markdown]
# No Change.

# %%
def image_scaling(x):
    return tf.image.per_image_standardization(x)

def distort(x):
    x = tf.image.resize_image_with_crop_or_pad(x, 40, 40)
    x = tf.random_crop(x, [32, 32, 3])
    x = tf.image.random_flip_left_right(x)
    return x

# %% [markdown]
# No Change.

# %%
def dataset_input_fn(params):
    dataset = tf.data.TFRecordDataset(
        params['filenames'],num_parallel_reads=params['threads'])
    dataset = dataset.map(parse_tfrecord, num_parallel_calls=params['threads'])
    dataset = dataset.map(lambda x,y: (image_scaling(x),y),num_parallel_calls=params['threads'])
    if params['mode']==tf.estimator.ModeKeys.TRAIN:
        dataset = dataset.map(lambda x,y: (distort(x),y),num_parallel_calls=params['threads'])
        dataset = dataset.shuffle(buffer_size=params['shuffle_buff'])
    dataset = dataset.repeat()
    dataset = dataset.batch(params['batch'])
    dataset = dataset.prefetch(8*params['batch'])
    return dataset

# %% [markdown]
# ### Logging Switch Parameter
#
# Implement logging parameter to turn on/off histogram logging.

# %%
model_params  = {'drop_out'      : 0.2,
                 'dense_units'   : 1024,
                 'learning_rate' : 1e-3,
                 'log'           : False # change to True
                }

# %% [markdown]
# No Change.

# %%
config = tf.estimator.RunConfig(save_checkpoints_secs = 300,keep_checkpoint_max = 5)

# %%
#Set model_fn
model_fn = cnnmodel_fn

# %% [markdown]
# No Change.

# %%
name = 'cnn_model/cnn_model_'
name = name + 'dense' + str(model_params['dense_units']) + '_'
name = name + 'drop' + str(model_params['drop_out']) + '_'
name = name + 'lr' + str(model_params['learning_rate']) + '_'
name = name + time.strftime("%Y%m%d%H%M%S")
model_dir  = os.path.join('./',name)

print(model_dir)
# Out:
# ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334

# %% [markdown]
# No Change.

# %%
estimator = tf.estimator.Estimator(
    model_fn=model_fn,model_dir=model_dir,params=model_params,config=config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 300, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa4ca277438>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# No Change.

# %%
train_files = !ls ./data/cifar10_data_00*.tfrecords
val_files   = !ls ./data/cifar10_data_01*.tfrecords

train_params = {'filenames'    : train_files,
                'mode'         : tf.estimator.ModeKeys.TRAIN,
                'threads'      : 16,
                'shuffle_buff' : 100000,
                'batch'        : 100
               }

eval_params  = {'filenames'    : val_files,
                'mode'         : tf.estimator.ModeKeys.EVAL,
                'threads'      : 8,
                'batch'        : 200
               }

# %% [markdown]
# No Change.

# %%
train_spec = tf.estimator.TrainSpec(input_fn=lambda: dataset_input_fn(train_params),max_steps=20000)
eval_spec  = tf.estimator.EvalSpec(input_fn=lambda: dataset_input_fn(eval_params),steps=10,throttle_secs=60)

# %% [markdown]
# No Change.

# %%
tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 60 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:loss = 2.3004072, step = 0
# INFO:tensorflow:global_step/sec: 69.3924
# INFO:tensorflow:loss = 2.299131, step = 100 (1.443 sec)
# INFO:tensorflow:global_step/sec: 80.3764
# INFO:tensorflow:loss = 2.3025303, step = 200 (1.244 sec)
# INFO:tensorflow:global_step/sec: 79.7862
# INFO:tensorflow:loss = 2.2930648, step = 300 (1.254 sec)
# INFO:tensorflow:global_step/sec: 83.4278
# INFO:tensorflow:loss = 2.2824376, step = 400 (1.199 sec)
# INFO:tensorflow:global_step/sec: 80.4771
# INFO:tensorflow:loss = 2.284475, step = 500 (1.243 sec)
# INFO:tensorflow:global_step/sec: 80.1368
# INFO:tensorflow:loss = 2.2861748, step = 600 (1.247 sec)
# INFO:tensorflow:global_step/sec: 78.988
# INFO:tensorflow:loss = 2.2570214, step = 700 (1.266 sec)
# INFO:tensorflow:global_step/sec: 82.4359
# INFO:tensorflow:loss = 2.2444758, step = 800 (1.213 sec)
# INFO:tensorflow:global_step/sec: 81.238
# INFO:tensorflow:loss = 2.2152338, step = 900 (1.232 sec)
# INFO:tensorflow:global_step/sec: 79.887
# INFO:tensorflow:loss = 2.2278986, step = 1000 (1.251 sec)
# INFO:tensorflow:global_step/sec: 78.794
# INFO:tensorflow:loss = 2.1756403, step = 1100 (1.269 sec)
# INFO:tensorflow:global_step/sec: 81.038
# INFO:tensorflow:loss = 2.2213168, step = 1200 (1.234 sec)
# INFO:tensorflow:global_step/sec: 82.6544
# INFO:tensorflow:loss = 2.1258738, step = 1300 (1.210 sec)
# INFO:tensorflow:global_step/sec: 80.5016
# INFO:tensorflow:loss = 2.1661992, step = 1400 (1.242 sec)
# INFO:tensorflow:global_step/sec: 79.7531
# INFO:tensorflow:loss = 2.1582918, step = 1500 (1.254 sec)
# INFO:tensorflow:global_step/sec: 79.4076
# INFO:tensorflow:loss = 2.0856059, step = 1600 (1.259 sec)
# INFO:tensorflow:global_step/sec: 83.1804
# INFO:tensorflow:loss = 2.075618, step = 1700 (1.204 sec)
# INFO:tensorflow:global_step/sec: 79.9212
# INFO:tensorflow:loss = 1.9484829, step = 1800 (1.253 sec)
# INFO:tensorflow:global_step/sec: 80.1779
# INFO:tensorflow:loss = 2.011498, step = 1900 (1.244 sec)
# INFO:tensorflow:global_step/sec: 80.2294
# INFO:tensorflow:loss = 2.0203648, step = 2000 (1.248 sec)
# INFO:tensorflow:global_step/sec: 83.1486
# INFO:tensorflow:loss = 1.9507021, step = 2100 (1.202 sec)
# INFO:tensorflow:global_step/sec: 80.8748
# INFO:tensorflow:loss = 2.066577, step = 2200 (1.239 sec)
# INFO:tensorflow:global_step/sec: 80.8465
# INFO:tensorflow:loss = 2.044307, step = 2300 (1.237 sec)
# INFO:tensorflow:global_step/sec: 79.5283
# INFO:tensorflow:loss = 1.9884092, step = 2400 (1.256 sec)
# INFO:tensorflow:global_step/sec: 82.1903
# INFO:tensorflow:loss = 2.0200138, step = 2500 (1.215 sec)
# INFO:tensorflow:global_step/sec: 79.9695
# INFO:tensorflow:loss = 1.9489679, step = 2600 (1.251 sec)
# INFO:tensorflow:global_step/sec: 80.466
# INFO:tensorflow:loss = 2.0841236, step = 2700 (1.243 sec)
# INFO:tensorflow:global_step/sec: 78.9503
# INFO:tensorflow:loss = 1.875424, step = 2800 (1.266 sec)
# INFO:tensorflow:global_step/sec: 81.5338
# INFO:tensorflow:loss = 1.9109927, step = 2900 (1.226 sec)
# INFO:tensorflow:global_step/sec: 82.208
# INFO:tensorflow:loss = 1.9434323, step = 3000 (1.217 sec)
# INFO:tensorflow:global_step/sec: 80.4876
# INFO:tensorflow:loss = 2.0672135, step = 3100 (1.243 sec)
# INFO:tensorflow:global_step/sec: 80.0977
# INFO:tensorflow:loss = 1.9217066, step = 3200 (1.248 sec)
# INFO:tensorflow:global_step/sec: 79.7681
# INFO:tensorflow:loss = 1.8393297, step = 3300 (1.254 sec)
# INFO:tensorflow:global_step/sec: 83.0846
# INFO:tensorflow:loss = 1.9998163, step = 3400 (1.203 sec)
# INFO:tensorflow:global_step/sec: 79.3515
# INFO:tensorflow:loss = 1.7926596, step = 3500 (1.263 sec)
# INFO:tensorflow:global_step/sec: 79.7231
# INFO:tensorflow:loss = 2.0263727, step = 3600 (1.253 sec)
# INFO:tensorflow:global_step/sec: 80.3411
# INFO:tensorflow:loss = 1.9116513, step = 3700 (1.245 sec)
# INFO:tensorflow:global_step/sec: 83.4785
# INFO:tensorflow:loss = 1.8161955, step = 3800 (1.197 sec)
# INFO:tensorflow:global_step/sec: 80.1583
# INFO:tensorflow:loss = 1.9219289, step = 3900 (1.248 sec)
# INFO:tensorflow:global_step/sec: 78.0238
# INFO:tensorflow:loss = 1.7849501, step = 4000 (1.282 sec)
# INFO:tensorflow:global_step/sec: 79.4584
# INFO:tensorflow:loss = 1.9771909, step = 4100 (1.258 sec)
# INFO:tensorflow:global_step/sec: 83.0349
# INFO:tensorflow:loss = 1.750353, step = 4200 (1.204 sec)
# INFO:tensorflow:Saving checkpoints for 4289 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.8858867.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-18-22:44:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-4289
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-18-22:44:41
# INFO:tensorflow:Saving dict for global step 4289: accuracy = 0.4275, global_step = 4289, loss = 1.6813114
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4289: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-4289
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-4289
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4289 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:loss = 1.7935648, step = 4289
# INFO:tensorflow:global_step/sec: 73.943
# INFO:tensorflow:loss = 1.793765, step = 4389 (1.354 sec)
# INFO:tensorflow:global_step/sec: 80.3757
# INFO:tensorflow:loss = 1.7779039, step = 4489 (1.246 sec)
# INFO:tensorflow:global_step/sec: 79.3456
# INFO:tensorflow:loss = 1.7574224, step = 4589 (1.259 sec)
# INFO:tensorflow:global_step/sec: 79.499
# INFO:tensorflow:loss = 1.8226587, step = 4689 (1.257 sec)
# INFO:tensorflow:global_step/sec: 83.2452
# INFO:tensorflow:loss = 1.8706633, step = 4789 (1.201 sec)
# INFO:tensorflow:global_step/sec: 80.0194
# INFO:tensorflow:loss = 1.7782577, step = 4889 (1.250 sec)
# INFO:tensorflow:global_step/sec: 79.6517
# INFO:tensorflow:loss = 1.7358071, step = 4989 (1.256 sec)
# INFO:tensorflow:global_step/sec: 79.8471
# INFO:tensorflow:loss = 1.7766515, step = 5089 (1.252 sec)
# INFO:tensorflow:global_step/sec: 83.0166
# INFO:tensorflow:loss = 1.7819116, step = 5189 (1.205 sec)
# INFO:tensorflow:global_step/sec: 80.3134
# INFO:tensorflow:loss = 1.7961789, step = 5289 (1.245 sec)
# INFO:tensorflow:global_step/sec: 80.415
# INFO:tensorflow:loss = 1.8396176, step = 5389 (1.244 sec)
# INFO:tensorflow:global_step/sec: 79.3047
# INFO:tensorflow:loss = 1.751036, step = 5489 (1.261 sec)
# INFO:tensorflow:global_step/sec: 81.8929
# INFO:tensorflow:loss = 1.6985412, step = 5589 (1.222 sec)
# INFO:tensorflow:global_step/sec: 81.7182
# INFO:tensorflow:loss = 1.7877548, step = 5689 (1.226 sec)
# INFO:tensorflow:global_step/sec: 80.4209
# INFO:tensorflow:loss = 1.7872472, step = 5789 (1.242 sec)
# INFO:tensorflow:global_step/sec: 80.1763
# INFO:tensorflow:loss = 1.804204, step = 5889 (1.247 sec)
# INFO:tensorflow:global_step/sec: 79.5162
# INFO:tensorflow:loss = 1.7006763, step = 5989 (1.257 sec)
# INFO:tensorflow:global_step/sec: 82.8744
# INFO:tensorflow:loss = 1.6680102, step = 6089 (1.209 sec)
# INFO:tensorflow:global_step/sec: 80.0485
# INFO:tensorflow:loss = 1.6878668, step = 6189 (1.249 sec)
# INFO:tensorflow:global_step/sec: 79.929
# INFO:tensorflow:loss = 1.6986961, step = 6289 (1.249 sec)
# INFO:tensorflow:global_step/sec: 79.6646
# INFO:tensorflow:loss = 1.7625489, step = 6389 (1.255 sec)
# INFO:tensorflow:global_step/sec: 83.3255
# INFO:tensorflow:loss = 1.7094547, step = 6489 (1.200 sec)
# INFO:tensorflow:global_step/sec: 80.0424
# INFO:tensorflow:loss = 1.5799818, step = 6589 (1.251 sec)
# INFO:tensorflow:global_step/sec: 78.4545
# INFO:tensorflow:loss = 1.7933893, step = 6689 (1.273 sec)
# INFO:tensorflow:global_step/sec: 79.5644
# INFO:tensorflow:loss = 1.694471, step = 6789 (1.258 sec)
# INFO:tensorflow:global_step/sec: 82.49
# INFO:tensorflow:loss = 1.6838815, step = 6889 (1.211 sec)
# INFO:tensorflow:global_step/sec: 80.2657
# INFO:tensorflow:loss = 1.7305954, step = 6989 (1.246 sec)
# INFO:tensorflow:global_step/sec: 80.2018
# INFO:tensorflow:loss = 1.6362232, step = 7089 (1.247 sec)
# INFO:tensorflow:global_step/sec: 80.0732
# INFO:tensorflow:loss = 1.8130628, step = 7189 (1.249 sec)
# INFO:tensorflow:global_step/sec: 81.3313
# INFO:tensorflow:loss = 1.548995, step = 7289 (1.229 sec)
# INFO:tensorflow:global_step/sec: 81.4546
# INFO:tensorflow:loss = 1.6268307, step = 7389 (1.228 sec)
# INFO:tensorflow:global_step/sec: 80.2673
# INFO:tensorflow:loss = 1.7538154, step = 7489 (1.246 sec)
# INFO:tensorflow:global_step/sec: 80.1836
# INFO:tensorflow:loss = 1.6976838, step = 7589 (1.247 sec)
# INFO:tensorflow:global_step/sec: 80.5425
# INFO:tensorflow:loss = 1.7623355, step = 7689 (1.242 sec)
# INFO:tensorflow:global_step/sec: 83.3658
# INFO:tensorflow:loss = 1.724737, step = 7789 (1.200 sec)
# INFO:tensorflow:global_step/sec: 80.4838
# INFO:tensorflow:loss = 1.617081, step = 7889 (1.242 sec)
# INFO:tensorflow:global_step/sec: 80.3216
# INFO:tensorflow:loss = 1.602846, step = 7989 (1.246 sec)
# INFO:tensorflow:global_step/sec: 80.2571
# INFO:tensorflow:loss = 1.5896574, step = 8089 (1.248 sec)
# INFO:tensorflow:global_step/sec: 82.1827
# INFO:tensorflow:loss = 1.7602886, step = 8189 (1.216 sec)
# INFO:tensorflow:global_step/sec: 80.0987
# INFO:tensorflow:loss = 1.7734758, step = 8289 (1.246 sec)
# INFO:tensorflow:global_step/sec: 79.751
# INFO:tensorflow:loss = 1.5879654, step = 8389 (1.255 sec)
# INFO:tensorflow:global_step/sec: 80.0092
# INFO:tensorflow:loss = 1.706614, step = 8489 (1.249 sec)
# INFO:tensorflow:global_step/sec: 82.6107
# INFO:tensorflow:loss = 1.7567232, step = 8589 (1.210 sec)
# INFO:tensorflow:global_step/sec: 79.125
# INFO:tensorflow:loss = 1.6783953, step = 8689 (1.264 sec)
# INFO:tensorflow:Saving checkpoints for 8743 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.4905857.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-18-22:45:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-8743
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-18-22:45:45
# INFO:tensorflow:Saving dict for global step 8743: accuracy = 0.502, global_step = 8743, loss = 1.4532259
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8743: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-8743
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-8743
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 8743 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:loss = 1.5243268, step = 8743
# INFO:tensorflow:global_step/sec: 73.4413
# INFO:tensorflow:loss = 1.5520738, step = 8843 (1.364 sec)
# INFO:tensorflow:global_step/sec: 80.3118
# INFO:tensorflow:loss = 1.6251868, step = 8943 (1.245 sec)
# INFO:tensorflow:global_step/sec: 79.7014
# INFO:tensorflow:loss = 1.6990006, step = 9043 (1.254 sec)
# INFO:tensorflow:global_step/sec: 80.1862
# INFO:tensorflow:loss = 1.6470829, step = 9143 (1.248 sec)
# INFO:tensorflow:global_step/sec: 83.4405
# INFO:tensorflow:loss = 1.6133777, step = 9243 (1.201 sec)
# INFO:tensorflow:global_step/sec: 79.1363
# INFO:tensorflow:loss = 1.4839792, step = 9343 (1.261 sec)
# INFO:tensorflow:global_step/sec: 79.8108
# INFO:tensorflow:loss = 1.590148, step = 9443 (1.255 sec)
# INFO:tensorflow:global_step/sec: 79.3309
# INFO:tensorflow:loss = 1.5749286, step = 9543 (1.259 sec)
# INFO:tensorflow:global_step/sec: 82.778
# INFO:tensorflow:loss = 1.6884097, step = 9643 (1.208 sec)
# INFO:tensorflow:global_step/sec: 80.4267
# INFO:tensorflow:loss = 1.5934812, step = 9743 (1.243 sec)
# INFO:tensorflow:global_step/sec: 80.6132
# INFO:tensorflow:loss = 1.5720526, step = 9843 (1.240 sec)
# INFO:tensorflow:global_step/sec: 79.3606
# INFO:tensorflow:loss = 1.61181, step = 9943 (1.263 sec)
# INFO:tensorflow:global_step/sec: 81.4356
# INFO:tensorflow:loss = 1.6318712, step = 10043 (1.225 sec)
# INFO:tensorflow:global_step/sec: 81.5485
# INFO:tensorflow:loss = 1.53279, step = 10143 (1.228 sec)
# INFO:tensorflow:global_step/sec: 79.9613
# INFO:tensorflow:loss = 1.6250705, step = 10243 (1.250 sec)
# INFO:tensorflow:global_step/sec: 80.1124
# INFO:tensorflow:loss = 1.4917352, step = 10343 (1.250 sec)
# INFO:tensorflow:global_step/sec: 80.8259
# INFO:tensorflow:loss = 1.645781, step = 10443 (1.235 sec)
# INFO:tensorflow:global_step/sec: 82.6597
# INFO:tensorflow:loss = 1.5200113, step = 10543 (1.212 sec)
# INFO:tensorflow:global_step/sec: 79.9503
# INFO:tensorflow:loss = 1.4999096, step = 10643 (1.250 sec)
# INFO:tensorflow:global_step/sec: 79.8572
# INFO:tensorflow:loss = 1.6424687, step = 10743 (1.251 sec)
# INFO:tensorflow:global_step/sec: 79.5605
# INFO:tensorflow:loss = 1.5623829, step = 10843 (1.258 sec)
# INFO:tensorflow:global_step/sec: 83.0308
# INFO:tensorflow:loss = 1.7129596, step = 10943 (1.203 sec)
# INFO:tensorflow:global_step/sec: 80.9247
# INFO:tensorflow:loss = 1.4436541, step = 11043 (1.236 sec)
# INFO:tensorflow:global_step/sec: 79.7754
# INFO:tensorflow:loss = 1.4953848, step = 11143 (1.253 sec)
# INFO:tensorflow:global_step/sec: 79.7183
# INFO:tensorflow:loss = 1.5902518, step = 11243 (1.254 sec)
# INFO:tensorflow:global_step/sec: 83.0315
# INFO:tensorflow:loss = 1.7622052, step = 11343 (1.205 sec)
# INFO:tensorflow:global_step/sec: 80.3676
# INFO:tensorflow:loss = 1.5672008, step = 11443 (1.248 sec)
# INFO:tensorflow:global_step/sec: 79.7855
# INFO:tensorflow:loss = 1.5831219, step = 11543 (1.249 sec)
# INFO:tensorflow:global_step/sec: 80.003
# INFO:tensorflow:loss = 1.6648351, step = 11643 (1.250 sec)
# INFO:tensorflow:global_step/sec: 81.2753
# INFO:tensorflow:loss = 1.4571404, step = 11743 (1.230 sec)
# INFO:tensorflow:global_step/sec: 81.8617
# INFO:tensorflow:loss = 1.5100452, step = 11843 (1.222 sec)
# INFO:tensorflow:global_step/sec: 80.1775
# INFO:tensorflow:loss = 1.3775476, step = 11943 (1.249 sec)
# INFO:tensorflow:global_step/sec: 80.0516
# INFO:tensorflow:loss = 1.5189394, step = 12043 (1.250 sec)
# INFO:tensorflow:global_step/sec: 79.5304
# INFO:tensorflow:loss = 1.5239087, step = 12143 (1.254 sec)
# INFO:tensorflow:global_step/sec: 82.9116
# INFO:tensorflow:loss = 1.6907681, step = 12243 (1.206 sec)
# INFO:tensorflow:global_step/sec: 80.0478
# INFO:tensorflow:loss = 1.5607976, step = 12343 (1.249 sec)
# INFO:tensorflow:global_step/sec: 79.855
# INFO:tensorflow:loss = 1.5285897, step = 12443 (1.255 sec)
# INFO:tensorflow:global_step/sec: 79.9045
# INFO:tensorflow:loss = 1.5542579, step = 12543 (1.250 sec)
# INFO:tensorflow:global_step/sec: 83.2894
# INFO:tensorflow:loss = 1.587014, step = 12643 (1.201 sec)
# INFO:tensorflow:global_step/sec: 80.0022
# INFO:tensorflow:loss = 1.5403047, step = 12743 (1.250 sec)
# INFO:tensorflow:global_step/sec: 79.2557
# INFO:tensorflow:loss = 1.4051012, step = 12843 (1.262 sec)
# INFO:tensorflow:global_step/sec: 79.5429
# INFO:tensorflow:loss = 1.5760376, step = 12943 (1.255 sec)
# INFO:tensorflow:global_step/sec: 82.8621
# INFO:tensorflow:loss = 1.4751347, step = 13043 (1.207 sec)
# INFO:tensorflow:global_step/sec: 79.6894
# INFO:tensorflow:loss = 1.4583795, step = 13143 (1.254 sec)
# INFO:tensorflow:Saving checkpoints for 13190 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.4768203.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-18-22:46:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-13190
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-18-22:46:48
# INFO:tensorflow:Saving dict for global step 13190: accuracy = 0.549, global_step = 13190, loss = 1.3281915
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13190: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-13190
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-13190
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13190 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:loss = 1.5690235, step = 13190
# INFO:tensorflow:global_step/sec: 74.2316
# INFO:tensorflow:loss = 1.4839212, step = 13290 (1.349 sec)
# INFO:tensorflow:global_step/sec: 79.8235
# INFO:tensorflow:loss = 1.4810413, step = 13390 (1.253 sec)
# INFO:tensorflow:global_step/sec: 80.5079
# INFO:tensorflow:loss = 1.4959134, step = 13490 (1.241 sec)
# INFO:tensorflow:global_step/sec: 79.1014
# INFO:tensorflow:loss = 1.5060492, step = 13590 (1.265 sec)
# INFO:tensorflow:global_step/sec: 83.0786
# INFO:tensorflow:loss = 1.5253972, step = 13690 (1.204 sec)
# INFO:tensorflow:global_step/sec: 79.6708
# INFO:tensorflow:loss = 1.5608125, step = 13790 (1.254 sec)
# INFO:tensorflow:global_step/sec: 79.7806
# INFO:tensorflow:loss = 1.4748415, step = 13890 (1.254 sec)
# INFO:tensorflow:global_step/sec: 79.4373
# INFO:tensorflow:loss = 1.5576413, step = 13990 (1.259 sec)
# INFO:tensorflow:global_step/sec: 83.1476
# INFO:tensorflow:loss = 1.2542737, step = 14090 (1.205 sec)
# INFO:tensorflow:global_step/sec: 80.1017
# INFO:tensorflow:loss = 1.4069383, step = 14190 (1.246 sec)
# INFO:tensorflow:global_step/sec: 80.5315
# INFO:tensorflow:loss = 1.3487698, step = 14290 (1.242 sec)
# INFO:tensorflow:global_step/sec: 79.0739
# INFO:tensorflow:loss = 1.4342107, step = 14390 (1.265 sec)
# INFO:tensorflow:global_step/sec: 81.4318
# INFO:tensorflow:loss = 1.5003705, step = 14490 (1.227 sec)
# INFO:tensorflow:global_step/sec: 81.0933
# INFO:tensorflow:loss = 1.4609853, step = 14590 (1.234 sec)
# INFO:tensorflow:global_step/sec: 80.1479
# INFO:tensorflow:loss = 1.387146, step = 14690 (1.247 sec)
# INFO:tensorflow:global_step/sec: 80.1994
# INFO:tensorflow:loss = 1.5414548, step = 14790 (1.248 sec)
# INFO:tensorflow:global_step/sec: 80.2756
# INFO:tensorflow:loss = 1.4959637, step = 14890 (1.245 sec)
# INFO:tensorflow:global_step/sec: 83.1105
# INFO:tensorflow:loss = 1.6131974, step = 14990 (1.204 sec)
# INFO:tensorflow:global_step/sec: 79.6248
# INFO:tensorflow:loss = 1.4903421, step = 15090 (1.258 sec)
# INFO:tensorflow:global_step/sec: 79.7629
# INFO:tensorflow:loss = 1.3333853, step = 15190 (1.254 sec)
# INFO:tensorflow:global_step/sec: 79.697
# INFO:tensorflow:loss = 1.3910328, step = 15290 (1.253 sec)
# INFO:tensorflow:global_step/sec: 83.1284
# INFO:tensorflow:loss = 1.4848275, step = 15390 (1.203 sec)
# INFO:tensorflow:global_step/sec: 79.5379
# INFO:tensorflow:loss = 1.4674622, step = 15490 (1.257 sec)
# INFO:tensorflow:global_step/sec: 79.665
# INFO:tensorflow:loss = 1.365932, step = 15590 (1.255 sec)
# INFO:tensorflow:global_step/sec: 80.1341
# INFO:tensorflow:loss = 1.3981292, step = 15690 (1.250 sec)
# INFO:tensorflow:global_step/sec: 82.7411
# INFO:tensorflow:loss = 1.3725244, step = 15790 (1.206 sec)
# INFO:tensorflow:global_step/sec: 80.2754
# INFO:tensorflow:loss = 1.2902216, step = 15890 (1.248 sec)
# INFO:tensorflow:global_step/sec: 79.9128
# INFO:tensorflow:loss = 1.3119541, step = 15990 (1.249 sec)
# INFO:tensorflow:global_step/sec: 79.8626
# INFO:tensorflow:loss = 1.2469887, step = 16090 (1.252 sec)
# INFO:tensorflow:global_step/sec: 81.8369
# INFO:tensorflow:loss = 1.5516696, step = 16190 (1.222 sec)
# INFO:tensorflow:global_step/sec: 81.0548
# INFO:tensorflow:loss = 1.6179353, step = 16290 (1.234 sec)
# INFO:tensorflow:global_step/sec: 80.2919
# INFO:tensorflow:loss = 1.5437459, step = 16390 (1.246 sec)
# INFO:tensorflow:global_step/sec: 79.9598
# INFO:tensorflow:loss = 1.4065038, step = 16490 (1.250 sec)
# INFO:tensorflow:global_step/sec: 81.2436
# INFO:tensorflow:loss = 1.3706251, step = 16590 (1.230 sec)
# INFO:tensorflow:global_step/sec: 82.925
# INFO:tensorflow:loss = 1.4116863, step = 16690 (1.206 sec)
# INFO:tensorflow:global_step/sec: 79.9099
# INFO:tensorflow:loss = 1.6709075, step = 16790 (1.251 sec)
# INFO:tensorflow:global_step/sec: 79.4635
# INFO:tensorflow:loss = 1.2814052, step = 16890 (1.261 sec)
# INFO:tensorflow:global_step/sec: 79.6342
# INFO:tensorflow:loss = 1.5355735, step = 16990 (1.254 sec)
# INFO:tensorflow:global_step/sec: 83.2643
# INFO:tensorflow:loss = 1.5216504, step = 17090 (1.204 sec)
# INFO:tensorflow:global_step/sec: 80.5595
# INFO:tensorflow:loss = 1.4757292, step = 17190 (1.239 sec)
# INFO:tensorflow:global_step/sec: 79.9192
# INFO:tensorflow:loss = 1.3950962, step = 17290 (1.251 sec)
# INFO:tensorflow:global_step/sec: 79.7867
# INFO:tensorflow:loss = 1.1963416, step = 17390 (1.253 sec)
# INFO:tensorflow:global_step/sec: 82.8178
# INFO:tensorflow:loss = 1.369023, step = 17490 (1.207 sec)
# INFO:tensorflow:global_step/sec: 79.8461
# INFO:tensorflow:loss = 1.3799388, step = 17590 (1.252 sec)
# INFO:tensorflow:Saving checkpoints for 17646 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.3470066.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-18-22:47:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-17646
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-18-22:47:52
# INFO:tensorflow:Saving dict for global step 17646: accuracy = 0.5905, global_step = 17646, loss = 1.2010434
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17646: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-17646
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-17646
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 17646 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:loss = 1.2065611, step = 17646
# INFO:tensorflow:global_step/sec: 74.2048
# INFO:tensorflow:loss = 1.3652741, step = 17746 (1.349 sec)
# INFO:tensorflow:global_step/sec: 78.9981
# INFO:tensorflow:loss = 1.3852019, step = 17846 (1.268 sec)
# INFO:tensorflow:global_step/sec: 79.1034
# INFO:tensorflow:loss = 1.4664831, step = 17946 (1.262 sec)
# INFO:tensorflow:global_step/sec: 79.6886
# INFO:tensorflow:loss = 1.3283837, step = 18046 (1.257 sec)
# INFO:tensorflow:global_step/sec: 83.0794
# INFO:tensorflow:loss = 1.2585534, step = 18146 (1.204 sec)
# INFO:tensorflow:global_step/sec: 80.1336
# INFO:tensorflow:loss = 1.3408105, step = 18246 (1.246 sec)
# INFO:tensorflow:global_step/sec: 78.9815
# INFO:tensorflow:loss = 1.2670864, step = 18346 (1.267 sec)
# INFO:tensorflow:global_step/sec: 79.8065
# INFO:tensorflow:loss = 1.2144876, step = 18446 (1.254 sec)
# INFO:tensorflow:global_step/sec: 83.3029
# INFO:tensorflow:loss = 1.4264684, step = 18546 (1.201 sec)
# INFO:tensorflow:global_step/sec: 79.7321
# INFO:tensorflow:loss = 1.2866089, step = 18646 (1.254 sec)
# INFO:tensorflow:global_step/sec: 80.4288
# INFO:tensorflow:loss = 1.3809047, step = 18746 (1.242 sec)
# INFO:tensorflow:global_step/sec: 79.8061
# INFO:tensorflow:loss = 1.4122481, step = 18846 (1.253 sec)
# INFO:tensorflow:global_step/sec: 82.1752
# INFO:tensorflow:loss = 1.4193513, step = 18946 (1.218 sec)
# INFO:tensorflow:global_step/sec: 81.2023
# INFO:tensorflow:loss = 1.4869555, step = 19046 (1.232 sec)
# INFO:tensorflow:global_step/sec: 80.5787
# INFO:tensorflow:loss = 1.3201027, step = 19146 (1.241 sec)
# INFO:tensorflow:global_step/sec: 79.5672
# INFO:tensorflow:loss = 1.6257626, step = 19246 (1.257 sec)
# INFO:tensorflow:global_step/sec: 80.3422
# INFO:tensorflow:loss = 1.4522257, step = 19346 (1.242 sec)
# INFO:tensorflow:global_step/sec: 82.2535
# INFO:tensorflow:loss = 1.3861035, step = 19446 (1.216 sec)
# INFO:tensorflow:global_step/sec: 80.3033
# INFO:tensorflow:loss = 1.2466905, step = 19546 (1.246 sec)
# INFO:tensorflow:global_step/sec: 79.5211
# INFO:tensorflow:loss = 1.356896, step = 19646 (1.257 sec)
# INFO:tensorflow:global_step/sec: 78.5492
# INFO:tensorflow:loss = 1.2074332, step = 19746 (1.273 sec)
# INFO:tensorflow:global_step/sec: 82.5955
# INFO:tensorflow:loss = 1.2718592, step = 19846 (1.211 sec)
# INFO:tensorflow:global_step/sec: 79.7987
# INFO:tensorflow:loss = 1.1641607, step = 19946 (1.255 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.5576484.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-18-22:48:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-18-22:48:29
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.596, global_step = 20000, loss = 1.1550031
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180718224334/model.ckpt-20000
# ({'accuracy': 0.596, 'loss': 1.1550031, 'global_step': 20000}, [])
