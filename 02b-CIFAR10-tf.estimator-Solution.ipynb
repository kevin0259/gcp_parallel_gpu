# %% [markdown]
# ## Pre-work Lab for Google Cloud ML Practitioner Training (Aug 6-10, 2018)
#
# In this lab, you will create a custom CNN model for the CIFAR10 data set.
#
# Helpful references:
# - https://www.youtube.com/watch?reload=9&v=eBbEDRsCmv4
# - https://www.tensorflow.org/guide/custom_estimators
# - https://www.tensorflow.org/guide/datasets_for_estimators

# %%
import tensorflow as tf
import time
import os
import numpy as np

# %% [markdown]
# ### DO: Create two functions that will be reused in your custom model function.
#
# _conv:
# - Convolution block to include conv, relu, and max pool.
# - Use tf.variable_scope.
# - Input should include feature, kernel (convolution filter), variable scope name
#
# _dense:
# - Dense block with relu.  Since last layer is logits, make relu switchable on/off.
# - Use tf.variable_scope.
# - Since last layer is logits, make relu switchable on/off.
# - Input should include feature, in/out sizes, variable scope name, relu(true/false)

# %%
# Convolution Block

def _conv(x,kernel,name):
    with tf.variable_scope(name):
        W = tf.get_variable(initializer=tf.truncated_normal(shape=kernel,stddev=0.01),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[kernel[3]]),name='b')
        conv = tf.nn.conv2d(x, W, strides=[1,1,1,1],padding='SAME')
        activation = tf.nn.relu(tf.add(conv,b))
        pool = tf.nn.max_pool(activation,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')
        return pool

# Dense Block

def _dense(x,size_in,size_out,name,relu=False):
    with tf.variable_scope(name):
        flat = tf.reshape(x,[-1,size_in])
        W = tf.get_variable(initializer=tf.truncated_normal([size_in,size_out],stddev=0.1),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[size_out]),name='b')
        activation = tf.add(tf.matmul(flat,W),b)
        if relu==True:
            activation = tf.nn.relu(activation)
        return activation

# %% [markdown]
# ### DO: Create custom model function.
#
# 5 sections of the model function
#
# #### 1. INFERENCE MODEL
#
# Recommended architecture:
# - conv1: kernel = 5x5x128
# - conv2: kernel = 5x5x128
# - conv3: kernel = 3x3x256
# - conv4: kernel = 3x3x512
# - dense: hidden_units (tunable hyperparam)
#
# Use:
# - tf.nn - this will allow for metric collection later.
#
# #### 2. CALCULATIONS AND METRICS
#
# Implement:
# - Prediction dictionary {classes, logits, probabilities}.
# - Loss function: Cross Entropy.
# - Accuracy for both training and eval using tf.metrics.
#
# #### 3. MODE = PREDICT
#
# Implement:
# - EstimatorSpec for PREDICT.
#
# #### 4. MODE = TRAIN
#
# Implement:
# - Optimizer = Stochastic Gradient Descent.
# - EstimatorSpec for TRAIN.
# - Optional: Exponential Decay Learning Rate.
#
# #### 5. MODE = EVAL
#
# Implement:
# - EstimatorSpec for EVAL.

# %%
def cnnmodel_fn(features, labels, mode, params):
    
    #### 1 INFERNCE MODEL
    
    input_layer = tf.reshape(features, [-1, 32, 32, 3])
    conv1 = _conv(input_layer,kernel=[5,5,3,128],name='conv1')
    conv2 = _conv(conv1,kernel=[5,5,128,128],name='conv2')
    conv3 = _conv(conv2,kernel=[3,3,128,256],name='conv3')
    conv4 = _conv(conv3,kernel=[3,3,256,512],name='conv4')
    dense = _dense(conv4,size_in=2*2*512,size_out=params['dense_units'],
                   name='Dense',relu=True)
    if mode==tf.estimator.ModeKeys.TRAIN:
        dense = tf.nn.dropout(dense,params['drop_out'])
    logits = _dense(dense,size_in=params['dense_units'],
                    size_out=10,name='Output',relu=False)
        
    #### 2 CALCULATIONS AND METRICS
    
    predictions = {"classes": tf.argmax(input=logits,axis=1),
                   "logits": logits,
                   "probabilities": tf.nn.softmax(logits,name='softmax')}
    export_outputs = {'predictions': tf.estimator.export.PredictOutput(predictions)}
    if (mode==tf.estimator.ModeKeys.TRAIN or mode==tf.estimator.ModeKeys.EVAL):
        loss = tf.losses.sparse_softmax_cross_entropy(labels=labels,logits=logits)
        accuracy = tf.metrics.accuracy(
            labels=labels, predictions=tf.argmax(logits,axis=1))
        metrics = {'accuracy':accuracy}
        
    #### 3 MODE = PREDICT
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(
            mode=mode, predictions=predictions, export_outputs=export_outputs)

    #### 4 MODE = TRAIN

    if mode == tf.estimator.ModeKeys.TRAIN:
        learning_rate = tf.train.exponential_decay(
            params['learning_rate'],tf.train.get_global_step(),
            decay_steps=100000,decay_rate=0.96)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss=loss,global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss, train_op=train_op)
    
    #### 5 MODE = EVAL
    
    if mode == tf.estimator.ModeKeys.EVAL:
        return tf.estimator.EstimatorSpec(
            mode=mode,loss=loss,eval_metric_ops=metrics)

# %% [markdown]
# ### DO: Create function to deserialize tfrecords files.
#
# Implement parse_tfrecord function:
# - Feature input: {idx: tf.int64, label: tf.int64, image: tf.string}
# - Return: image, label

# %%
def parse_tfrecord(example):
    feature={'idx'     : tf.FixedLenFeature((), tf.int64),
             'label'   : tf.FixedLenFeature((), tf.int64),
             'image'   : tf.FixedLenFeature((), tf.string, default_value="")}
    parsed = tf.parse_single_example(example, feature)
    image = tf.decode_raw(parsed['image'],tf.float64)
    image = tf.cast(image,tf.float32)
    image = tf.reshape(image,[32,32,3])
    return image, parsed['label']

# %% [markdown]
# ### DO: Create two helper functions:
#
# Implement image_scaling function:
# - Image scaling.
# - Applied always
#
# Implement distort function:
# - Applied only in training.
# - Resize, crop, flip randomly.

# %%
def image_scaling(x):
    return tf.image.per_image_standardization(x)

def distort(x):
    x = tf.image.resize_image_with_crop_or_pad(x, 40, 40)
    x = tf.random_crop(x, [32, 32, 3])
    x = tf.image.random_flip_left_right(x)
    return x

# %% [markdown]
# ### DO: Create input function using tf.data
#
# Create dataset_input_fn that implements:
# - Use TFRecordDataset to read tfrecord files.
# - Apply parse function you created above.
# - Apply image scaling function you created above.
# - Apply distort function on for training.
# - Suffle only for training.
# - Use prefetch
# - Optional: parallelize threads wherever possible.

# %%
def dataset_input_fn(params):
    dataset = tf.data.TFRecordDataset(
        params['filenames'],num_parallel_reads=params['threads'])
    dataset = dataset.map(parse_tfrecord, num_parallel_calls=params['threads'])
    dataset = dataset.map(lambda x,y: (image_scaling(x),y),num_parallel_calls=params['threads'])
    if params['mode']==tf.estimator.ModeKeys.TRAIN:
        dataset = dataset.map(lambda x,y: (distort(x),y),num_parallel_calls=params['threads'])
        dataset = dataset.shuffle(buffer_size=params['shuffle_buff'])
    dataset = dataset.repeat()
    dataset = dataset.batch(params['batch'])
    dataset = dataset.prefetch(8*params['batch'])
    return dataset

# %% [markdown]
# Create dictionary for parameters

# %%
model_params  = {'drop_out'      : 0.2,
                 'dense_units'   : 1024,
                 'learning_rate' : 1e-3
                }

# %% [markdown]
# ### DO: Create RunConfig
#
# Implement RunConfig:
# - Save checkpoints ever 300 seconds.
# - Keep up to 5 checkpoint history.

# %%
config = tf.estimator.RunConfig(save_checkpoints_secs = 300,keep_checkpoint_max = 5)

# %%
#Set model_fn
model_fn = cnnmodel_fn

# %% [markdown]
# Set model directory.  This is to make sorting out runs more easily.

# %%
name = 'cnn_model/cnn_model_'
name = name + 'dense' + str(model_params['dense_units']) + '_'
name = name + 'drop' + str(model_params['drop_out']) + '_'
name = name + 'lr' + str(model_params['learning_rate']) + '_'
name = name + time.strftime("%Y%m%d%H%M%S")
model_dir  = os.path.join('./',name)

print(model_dir)
# Out:
# ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201

# %% [markdown]
# ### DO: Create tf.estimator

# %%
estimator = tf.estimator.Estimator(
    model_fn=model_fn,model_dir=model_dir,params=model_params,config=config)
# Out:
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_global_id_in_cluster': 0, '_task_id': 0, '_train_distribute': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f00207eb2b0>, '_save_checkpoints_secs': 300, '_tf_random_seed': None, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': './cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201', '_save_summary_steps': 100, '_num_worker_replicas': 1, '_task_type': 'worker', '_service': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_is_chief': True, '_master': '', '_session_config': None}

# %% [markdown]
# Set parameters for input functions.

# %%
train_files = !ls ./data/cifar10_data_00*.tfrecords
val_files   = !ls ./data/cifar10_data_01*.tfrecords

train_params = {'filenames'    : train_files,
                'mode'         : tf.estimator.ModeKeys.TRAIN,
                'threads'      : 16,
                'shuffle_buff' : 100000,
                'batch'        : 100
               }

eval_params  = {'filenames'    : val_files,
                'mode'         : tf.estimator.ModeKeys.EVAL,
                'threads'      : 8,
                'batch'        : 200
               }

# %% [markdown]
# ### DO: TrainSpec and EvalSpec
#
# TranSpec:
# - Use train_params.
# - End after 20,000 steps.
#
# EvalSpec:
# - Use eval_params.
# - 10 steps.
# - Eval executes every 60 seconds or training time (production will be much longer).

# %%
train_spec = tf.estimator.TrainSpec(input_fn=lambda: dataset_input_fn(train_params),max_steps=20000)
eval_spec  = tf.estimator.EvalSpec(input_fn=lambda: dataset_input_fn(eval_params),steps=10,throttle_secs=60)

# %% [markdown]
# ### DO: Run training and eval

# %%
tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 60 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:step = 0, loss = 2.301232
# INFO:tensorflow:global_step/sec: 71.2852
# INFO:tensorflow:step = 100, loss = 2.3005333 (1.405 sec)
# INFO:tensorflow:global_step/sec: 81.8723
# INFO:tensorflow:step = 200, loss = 2.2963178 (1.221 sec)
# INFO:tensorflow:global_step/sec: 82.0664
# INFO:tensorflow:step = 300, loss = 2.2945645 (1.218 sec)
# INFO:tensorflow:global_step/sec: 79.9502
# INFO:tensorflow:step = 400, loss = 2.29304 (1.251 sec)
# INFO:tensorflow:global_step/sec: 81.4147
# INFO:tensorflow:step = 500, loss = 2.2795346 (1.234 sec)
# INFO:tensorflow:global_step/sec: 81.1576
# INFO:tensorflow:step = 600, loss = 2.2933962 (1.227 sec)
# INFO:tensorflow:global_step/sec: 81.4087
# INFO:tensorflow:step = 700, loss = 2.278963 (1.228 sec)
# INFO:tensorflow:global_step/sec: 81.1267
# INFO:tensorflow:step = 800, loss = 2.2781534 (1.233 sec)
# INFO:tensorflow:global_step/sec: 81.4149
# INFO:tensorflow:step = 900, loss = 2.2767494 (1.228 sec)
# INFO:tensorflow:global_step/sec: 82.0281
# INFO:tensorflow:step = 1000, loss = 2.264996 (1.219 sec)
# INFO:tensorflow:global_step/sec: 79.8347
# INFO:tensorflow:step = 1100, loss = 2.272886 (1.252 sec)
# INFO:tensorflow:global_step/sec: 81.9259
# INFO:tensorflow:step = 1200, loss = 2.1938212 (1.221 sec)
# INFO:tensorflow:global_step/sec: 82.2026
# INFO:tensorflow:step = 1300, loss = 2.2525485 (1.216 sec)
# INFO:tensorflow:global_step/sec: 80.9384
# INFO:tensorflow:step = 1400, loss = 2.1993124 (1.235 sec)
# INFO:tensorflow:global_step/sec: 80.6576
# INFO:tensorflow:step = 1500, loss = 2.078679 (1.240 sec)
# INFO:tensorflow:global_step/sec: 81.5097
# INFO:tensorflow:step = 1600, loss = 2.096473 (1.227 sec)
# INFO:tensorflow:global_step/sec: 81.8706
# INFO:tensorflow:step = 1700, loss = 2.1147304 (1.221 sec)
# INFO:tensorflow:global_step/sec: 80.4219
# INFO:tensorflow:step = 1800, loss = 2.2002795 (1.243 sec)
# INFO:tensorflow:global_step/sec: 81.3434
# INFO:tensorflow:step = 1900, loss = 2.1033394 (1.229 sec)
# INFO:tensorflow:global_step/sec: 82.3115
# INFO:tensorflow:step = 2000, loss = 2.069377 (1.216 sec)
# INFO:tensorflow:global_step/sec: 81.8149
# INFO:tensorflow:step = 2100, loss = 2.0054488 (1.222 sec)
# INFO:tensorflow:global_step/sec: 80.8623
# INFO:tensorflow:step = 2200, loss = 1.9093434 (1.236 sec)
# INFO:tensorflow:global_step/sec: 80.1937
# INFO:tensorflow:step = 2300, loss = 2.126059 (1.247 sec)
# INFO:tensorflow:global_step/sec: 81.8387
# INFO:tensorflow:step = 2400, loss = 2.1041472 (1.223 sec)
# INFO:tensorflow:global_step/sec: 81.7854
# INFO:tensorflow:step = 2500, loss = 1.968173 (1.223 sec)
# INFO:tensorflow:global_step/sec: 81.7414
# INFO:tensorflow:step = 2600, loss = 1.8511128 (1.223 sec)
# INFO:tensorflow:global_step/sec: 79.8636
# INFO:tensorflow:step = 2700, loss = 1.9527516 (1.251 sec)
# INFO:tensorflow:global_step/sec: 81.2965
# INFO:tensorflow:step = 2800, loss = 1.9669076 (1.230 sec)
# INFO:tensorflow:global_step/sec: 82.463
# INFO:tensorflow:step = 2900, loss = 1.9785577 (1.213 sec)
# INFO:tensorflow:global_step/sec: 81.8682
# INFO:tensorflow:step = 3000, loss = 1.8973182 (1.221 sec)
# INFO:tensorflow:global_step/sec: 81.0849
# INFO:tensorflow:step = 3100, loss = 1.9317541 (1.239 sec)
# INFO:tensorflow:global_step/sec: 80.033
# INFO:tensorflow:step = 3200, loss = 1.8708882 (1.243 sec)
# INFO:tensorflow:global_step/sec: 81.5047
# INFO:tensorflow:step = 3300, loss = 1.9997072 (1.228 sec)
# INFO:tensorflow:global_step/sec: 81.6101
# INFO:tensorflow:step = 3400, loss = 2.0841596 (1.225 sec)
# INFO:tensorflow:global_step/sec: 81.729
# INFO:tensorflow:step = 3500, loss = 1.8626809 (1.224 sec)
# INFO:tensorflow:global_step/sec: 80.7805
# INFO:tensorflow:step = 3600, loss = 2.015294 (1.237 sec)
# INFO:tensorflow:global_step/sec: 80.7842
# INFO:tensorflow:step = 3700, loss = 1.8932244 (1.238 sec)
# INFO:tensorflow:global_step/sec: 82.2857
# INFO:tensorflow:step = 3800, loss = 1.924162 (1.215 sec)
# INFO:tensorflow:global_step/sec: 81.5637
# INFO:tensorflow:step = 3900, loss = 1.9060358 (1.227 sec)
# INFO:tensorflow:global_step/sec: 81.2875
# INFO:tensorflow:step = 4000, loss = 1.8378899 (1.230 sec)
# INFO:tensorflow:global_step/sec: 80.517
# INFO:tensorflow:step = 4100, loss = 1.9911367 (1.241 sec)
# INFO:tensorflow:global_step/sec: 81.6671
# INFO:tensorflow:step = 4200, loss = 1.8277843 (1.225 sec)
# INFO:tensorflow:global_step/sec: 80.9928
# INFO:tensorflow:step = 4300, loss = 1.8498185 (1.235 sec)
# INFO:tensorflow:global_step/sec: 81.723
# INFO:tensorflow:step = 4400, loss = 1.9045174 (1.224 sec)
# INFO:tensorflow:global_step/sec: 80.7511
# INFO:tensorflow:step = 4500, loss = 1.894682 (1.239 sec)
# INFO:tensorflow:Saving checkpoints for 4573 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.806638.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-16-02:43:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt-4573
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-16-02:43:08
# INFO:tensorflow:Saving dict for global step 4573: accuracy = 0.403, global_step = 4573, loss = 1.699824
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt-4573
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4574 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:step = 4573, loss = 1.7420615
# INFO:tensorflow:global_step/sec: 70.8654
# INFO:tensorflow:step = 4673, loss = 1.7245117 (1.413 sec)
# INFO:tensorflow:global_step/sec: 80.3586
# INFO:tensorflow:step = 4773, loss = 1.66614 (1.245 sec)
# INFO:tensorflow:global_step/sec: 81.5629
# INFO:tensorflow:step = 4873, loss = 1.9211377 (1.226 sec)
# INFO:tensorflow:global_step/sec: 79.3238
# INFO:tensorflow:step = 4973, loss = 1.7506415 (1.260 sec)
# INFO:tensorflow:global_step/sec: 81.503
# INFO:tensorflow:step = 5073, loss = 1.7037183 (1.227 sec)
# INFO:tensorflow:global_step/sec: 81.1553
# INFO:tensorflow:step = 5173, loss = 1.8510597 (1.232 sec)
# INFO:tensorflow:global_step/sec: 80.5899
# INFO:tensorflow:step = 5273, loss = 1.7912692 (1.240 sec)
# INFO:tensorflow:global_step/sec: 81.1234
# INFO:tensorflow:step = 5373, loss = 1.9424691 (1.233 sec)
# INFO:tensorflow:global_step/sec: 81.482
# INFO:tensorflow:step = 5473, loss = 1.7920575 (1.228 sec)
# INFO:tensorflow:global_step/sec: 81.6281
# INFO:tensorflow:step = 5573, loss = 1.7118262 (1.225 sec)
# INFO:tensorflow:global_step/sec: 79.8199
# INFO:tensorflow:step = 5673, loss = 1.8508277 (1.253 sec)
# INFO:tensorflow:global_step/sec: 81.6177
# INFO:tensorflow:step = 5773, loss = 1.8683572 (1.225 sec)
# INFO:tensorflow:global_step/sec: 82.1984
# INFO:tensorflow:step = 5873, loss = 1.7135253 (1.217 sec)
# INFO:tensorflow:global_step/sec: 80.5654
# INFO:tensorflow:step = 5973, loss = 1.7094727 (1.241 sec)
# INFO:tensorflow:global_step/sec: 80.68
# INFO:tensorflow:step = 6073, loss = 1.7913885 (1.240 sec)
# INFO:tensorflow:global_step/sec: 81.8462
# INFO:tensorflow:step = 6173, loss = 1.6941032 (1.222 sec)
# INFO:tensorflow:global_step/sec: 81.8282
# INFO:tensorflow:step = 6273, loss = 1.7849408 (1.222 sec)
# INFO:tensorflow:global_step/sec: 80.4221
# INFO:tensorflow:step = 6373, loss = 1.7139572 (1.243 sec)
# INFO:tensorflow:global_step/sec: 81.2249
# INFO:tensorflow:step = 6473, loss = 1.56716 (1.231 sec)
# INFO:tensorflow:global_step/sec: 82.6961
# INFO:tensorflow:step = 6573, loss = 1.6852149 (1.210 sec)
# INFO:tensorflow:global_step/sec: 81.1919
# INFO:tensorflow:step = 6673, loss = 1.8207331 (1.231 sec)
# INFO:tensorflow:global_step/sec: 82.7033
# INFO:tensorflow:step = 6773, loss = 1.725018 (1.209 sec)
# INFO:tensorflow:global_step/sec: 79.9361
# INFO:tensorflow:step = 6873, loss = 1.7123874 (1.250 sec)
# INFO:tensorflow:global_step/sec: 81.4746
# INFO:tensorflow:step = 6973, loss = 1.7766834 (1.229 sec)
# INFO:tensorflow:global_step/sec: 81.7955
# INFO:tensorflow:step = 7073, loss = 1.7034202 (1.222 sec)
# INFO:tensorflow:global_step/sec: 81.7728
# INFO:tensorflow:step = 7173, loss = 1.9485043 (1.223 sec)
# INFO:tensorflow:global_step/sec: 80.4855
# INFO:tensorflow:step = 7273, loss = 1.6779044 (1.242 sec)
# INFO:tensorflow:global_step/sec: 81.3982
# INFO:tensorflow:step = 7373, loss = 1.6468837 (1.228 sec)
# INFO:tensorflow:global_step/sec: 81.984
# INFO:tensorflow:step = 7473, loss = 1.8152568 (1.221 sec)
# INFO:tensorflow:global_step/sec: 81.8039
# INFO:tensorflow:step = 7573, loss = 1.856676 (1.222 sec)
# INFO:tensorflow:global_step/sec: 81.1331
# INFO:tensorflow:step = 7673, loss = 1.790543 (1.233 sec)
# INFO:tensorflow:global_step/sec: 80.4397
# INFO:tensorflow:step = 7773, loss = 1.7963805 (1.243 sec)
# INFO:tensorflow:global_step/sec: 81.7663
# INFO:tensorflow:step = 7873, loss = 1.6735104 (1.223 sec)
# INFO:tensorflow:global_step/sec: 81.3902
# INFO:tensorflow:step = 7973, loss = 1.4928124 (1.229 sec)
# INFO:tensorflow:global_step/sec: 81.749
# INFO:tensorflow:step = 8073, loss = 1.7318826 (1.224 sec)
# INFO:tensorflow:global_step/sec: 80.4296
# INFO:tensorflow:step = 8173, loss = 1.6580881 (1.243 sec)
# INFO:tensorflow:global_step/sec: 81.0858
# INFO:tensorflow:step = 8273, loss = 1.4681351 (1.233 sec)
# INFO:tensorflow:global_step/sec: 82.0202
# INFO:tensorflow:step = 8373, loss = 1.5699674 (1.220 sec)
# INFO:tensorflow:global_step/sec: 81.3659
# INFO:tensorflow:step = 8473, loss = 1.6737496 (1.235 sec)
# INFO:tensorflow:global_step/sec: 80.4031
# INFO:tensorflow:step = 8573, loss = 1.5950971 (1.237 sec)
# INFO:tensorflow:global_step/sec: 79.9411
# INFO:tensorflow:step = 8673, loss = 1.6003387 (1.251 sec)
# INFO:tensorflow:global_step/sec: 82.0341
# INFO:tensorflow:step = 8773, loss = 1.757806 (1.220 sec)
# INFO:tensorflow:global_step/sec: 81.8011
# INFO:tensorflow:step = 8873, loss = 1.6358637 (1.222 sec)
# INFO:tensorflow:global_step/sec: 82.0698
# INFO:tensorflow:step = 8973, loss = 1.5266206 (1.219 sec)
# INFO:tensorflow:global_step/sec: 80.5436
# INFO:tensorflow:step = 9073, loss = 1.6200051 (1.241 sec)
# INFO:tensorflow:Saving checkpoints for 9157 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.6070435.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-16-02:44:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt-9157
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-16-02:44:09
# INFO:tensorflow:Saving dict for global step 9157: accuracy = 0.4775, global_step = 9157, loss = 1.4532899
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt-9157
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9158 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:step = 9157, loss = 1.7616123
# INFO:tensorflow:global_step/sec: 71.9476
# INFO:tensorflow:step = 9257, loss = 1.4746807 (1.392 sec)
# INFO:tensorflow:global_step/sec: 81.6641
# INFO:tensorflow:step = 9357, loss = 1.8308346 (1.224 sec)
# INFO:tensorflow:global_step/sec: 81.7591
# INFO:tensorflow:step = 9457, loss = 1.5483266 (1.223 sec)
# INFO:tensorflow:global_step/sec: 79.4285
# INFO:tensorflow:step = 9557, loss = 1.6720392 (1.259 sec)
# INFO:tensorflow:global_step/sec: 81.8171
# INFO:tensorflow:step = 9657, loss = 1.6706226 (1.222 sec)
# INFO:tensorflow:global_step/sec: 81.6099
# INFO:tensorflow:step = 9757, loss = 1.9624166 (1.226 sec)
# INFO:tensorflow:global_step/sec: 80.2109
# INFO:tensorflow:step = 9857, loss = 1.7100929 (1.246 sec)
# INFO:tensorflow:global_step/sec: 80.828
# INFO:tensorflow:step = 9957, loss = 1.4819788 (1.237 sec)
# INFO:tensorflow:global_step/sec: 81.4373
# INFO:tensorflow:step = 10057, loss = 1.6082078 (1.228 sec)
# INFO:tensorflow:global_step/sec: 81.7822
# INFO:tensorflow:step = 10157, loss = 1.6029892 (1.223 sec)
# INFO:tensorflow:global_step/sec: 80.1782
# INFO:tensorflow:step = 10257, loss = 1.6813523 (1.247 sec)
# INFO:tensorflow:global_step/sec: 81.9054
# INFO:tensorflow:step = 10357, loss = 1.6154557 (1.220 sec)
# INFO:tensorflow:global_step/sec: 81.8619
# INFO:tensorflow:step = 10457, loss = 1.5039977 (1.222 sec)
# INFO:tensorflow:global_step/sec: 81.1367
# INFO:tensorflow:step = 10557, loss = 1.7614437 (1.232 sec)
# INFO:tensorflow:global_step/sec: 80.6046
# INFO:tensorflow:step = 10657, loss = 1.5207144 (1.242 sec)
# INFO:tensorflow:global_step/sec: 81.7431
# INFO:tensorflow:step = 10757, loss = 1.6891315 (1.221 sec)
# INFO:tensorflow:global_step/sec: 81.9682
# INFO:tensorflow:step = 10857, loss = 1.5359282 (1.221 sec)
# INFO:tensorflow:global_step/sec: 80.8174
# INFO:tensorflow:step = 10957, loss = 1.6408043 (1.237 sec)
# INFO:tensorflow:global_step/sec: 81.4197
# INFO:tensorflow:step = 11057, loss = 1.6483771 (1.228 sec)
# INFO:tensorflow:global_step/sec: 81.9359
# INFO:tensorflow:step = 11157, loss = 1.573521 (1.221 sec)
# INFO:tensorflow:global_step/sec: 81.2012
# INFO:tensorflow:step = 11257, loss = 1.5996237 (1.232 sec)
# INFO:tensorflow:global_step/sec: 81.6779
# INFO:tensorflow:step = 11357, loss = 1.5169182 (1.223 sec)
# INFO:tensorflow:global_step/sec: 80.7487
# INFO:tensorflow:step = 11457, loss = 1.5659585 (1.238 sec)
# INFO:tensorflow:global_step/sec: 81.8248
# INFO:tensorflow:step = 11557, loss = 1.5441154 (1.222 sec)
# INFO:tensorflow:global_step/sec: 80.8042
# INFO:tensorflow:step = 11657, loss = 1.439186 (1.238 sec)
# INFO:tensorflow:global_step/sec: 81.5672
# INFO:tensorflow:step = 11757, loss = 1.575021 (1.232 sec)
# INFO:tensorflow:global_step/sec: 80.1783
# INFO:tensorflow:step = 11857, loss = 1.5198861 (1.241 sec)
# INFO:tensorflow:global_step/sec: 81.8207
# INFO:tensorflow:step = 11957, loss = 1.3926986 (1.223 sec)
# INFO:tensorflow:global_step/sec: 82.4092
# INFO:tensorflow:step = 12057, loss = 1.2909827 (1.214 sec)
# INFO:tensorflow:global_step/sec: 81.2413
# INFO:tensorflow:step = 12157, loss = 1.5101726 (1.231 sec)
# INFO:tensorflow:global_step/sec: 81.0824
# INFO:tensorflow:step = 12257, loss = 1.423252 (1.233 sec)
# INFO:tensorflow:global_step/sec: 80.3447
# INFO:tensorflow:step = 12357, loss = 1.500907 (1.244 sec)
# INFO:tensorflow:global_step/sec: 81.8076
# INFO:tensorflow:step = 12457, loss = 1.6874678 (1.223 sec)
# INFO:tensorflow:global_step/sec: 81.7433
# INFO:tensorflow:step = 12557, loss = 1.6059254 (1.223 sec)
# INFO:tensorflow:global_step/sec: 81.8525
# INFO:tensorflow:step = 12657, loss = 1.6649693 (1.222 sec)
# INFO:tensorflow:global_step/sec: 80.1321
# INFO:tensorflow:step = 12757, loss = 1.4635293 (1.248 sec)
# INFO:tensorflow:global_step/sec: 81.264
# INFO:tensorflow:step = 12857, loss = 1.6357358 (1.230 sec)
# INFO:tensorflow:global_step/sec: 82.3261
# INFO:tensorflow:step = 12957, loss = 1.5701492 (1.216 sec)
# INFO:tensorflow:global_step/sec: 81.7592
# INFO:tensorflow:step = 13057, loss = 1.3949924 (1.223 sec)
# INFO:tensorflow:global_step/sec: 81.0619
# INFO:tensorflow:step = 13157, loss = 1.6359254 (1.233 sec)
# INFO:tensorflow:global_step/sec: 80.1239
# INFO:tensorflow:step = 13257, loss = 1.4610268 (1.248 sec)
# INFO:tensorflow:global_step/sec: 81.762
# INFO:tensorflow:step = 13357, loss = 1.6132114 (1.223 sec)
# INFO:tensorflow:global_step/sec: 82.0323
# INFO:tensorflow:step = 13457, loss = 1.5508478 (1.220 sec)
# INFO:tensorflow:global_step/sec: 82.0305
# INFO:tensorflow:step = 13557, loss = 1.4997134 (1.218 sec)
# INFO:tensorflow:global_step/sec: 81.331
# INFO:tensorflow:step = 13657, loss = 1.6293482 (1.230 sec)
# INFO:tensorflow:Saving checkpoints for 13745 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.4567245.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-16-02:45:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt-13745
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-16-02:45:10
# INFO:tensorflow:Saving dict for global step 13745: accuracy = 0.5315, global_step = 13745, loss = 1.307666
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt-13745
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13746 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:step = 13745, loss = 1.3801143
# INFO:tensorflow:global_step/sec: 71.6571
# INFO:tensorflow:step = 13845, loss = 1.4665588 (1.397 sec)
# INFO:tensorflow:global_step/sec: 81.6985
# INFO:tensorflow:step = 13945, loss = 1.5793138 (1.225 sec)
# INFO:tensorflow:global_step/sec: 81.5993
# INFO:tensorflow:step = 14045, loss = 1.4395015 (1.226 sec)
# INFO:tensorflow:global_step/sec: 79.8522
# INFO:tensorflow:step = 14145, loss = 1.4545249 (1.252 sec)
# INFO:tensorflow:global_step/sec: 82.0992
# INFO:tensorflow:step = 14245, loss = 1.7227436 (1.218 sec)
# INFO:tensorflow:global_step/sec: 81.6933
# INFO:tensorflow:step = 14345, loss = 1.3709008 (1.224 sec)
# INFO:tensorflow:global_step/sec: 80.7497
# INFO:tensorflow:step = 14445, loss = 1.3751138 (1.238 sec)
# INFO:tensorflow:global_step/sec: 81.2276
# INFO:tensorflow:step = 14545, loss = 1.468517 (1.232 sec)
# INFO:tensorflow:global_step/sec: 81.1811
# INFO:tensorflow:step = 14645, loss = 1.4666574 (1.237 sec)
# INFO:tensorflow:global_step/sec: 81.5943
# INFO:tensorflow:step = 14745, loss = 1.4145275 (1.219 sec)
# INFO:tensorflow:global_step/sec: 79.5128
# INFO:tensorflow:step = 14845, loss = 1.3927815 (1.258 sec)
# INFO:tensorflow:global_step/sec: 81.891
# INFO:tensorflow:step = 14945, loss = 1.2846113 (1.222 sec)
# INFO:tensorflow:global_step/sec: 81.9673
# INFO:tensorflow:step = 15045, loss = 1.5539588 (1.219 sec)
# INFO:tensorflow:global_step/sec: 80.1877
# INFO:tensorflow:step = 15145, loss = 1.5280013 (1.247 sec)
# INFO:tensorflow:global_step/sec: 80.3077
# INFO:tensorflow:step = 15245, loss = 1.4312495 (1.246 sec)
# INFO:tensorflow:global_step/sec: 81.4637
# INFO:tensorflow:step = 15345, loss = 1.4458641 (1.227 sec)
# INFO:tensorflow:global_step/sec: 82.7791
# INFO:tensorflow:step = 15445, loss = 1.2809281 (1.208 sec)
# INFO:tensorflow:global_step/sec: 80.3575
# INFO:tensorflow:step = 15545, loss = 1.5546085 (1.244 sec)
# INFO:tensorflow:global_step/sec: 81.3586
# INFO:tensorflow:step = 15645, loss = 1.4455593 (1.229 sec)
# INFO:tensorflow:global_step/sec: 82.2737
# INFO:tensorflow:step = 15745, loss = 1.5028566 (1.216 sec)
# INFO:tensorflow:global_step/sec: 81.154
# INFO:tensorflow:step = 15845, loss = 1.299693 (1.233 sec)
# INFO:tensorflow:global_step/sec: 81.7664
# INFO:tensorflow:step = 15945, loss = 1.4820393 (1.223 sec)
# INFO:tensorflow:global_step/sec: 80.3782
# INFO:tensorflow:step = 16045, loss = 1.4406067 (1.244 sec)
# INFO:tensorflow:global_step/sec: 81.888
# INFO:tensorflow:step = 16145, loss = 1.3096459 (1.222 sec)
# INFO:tensorflow:global_step/sec: 82.321
# INFO:tensorflow:step = 16245, loss = 1.4503475 (1.220 sec)
# INFO:tensorflow:global_step/sec: 81.1503
# INFO:tensorflow:step = 16345, loss = 1.486817 (1.227 sec)
# INFO:tensorflow:global_step/sec: 79.915
# INFO:tensorflow:step = 16445, loss = 1.3858658 (1.251 sec)
# INFO:tensorflow:global_step/sec: 81.4405
# INFO:tensorflow:step = 16545, loss = 1.4474956 (1.228 sec)
# INFO:tensorflow:global_step/sec: 82.2464
# INFO:tensorflow:step = 16645, loss = 1.4871962 (1.221 sec)
# INFO:tensorflow:global_step/sec: 81.3444
# INFO:tensorflow:step = 16745, loss = 1.2186338 (1.225 sec)
# INFO:tensorflow:global_step/sec: 80.9717
# INFO:tensorflow:step = 16845, loss = 1.4622868 (1.235 sec)
# INFO:tensorflow:global_step/sec: 79.9977
# INFO:tensorflow:step = 16945, loss = 1.3870186 (1.249 sec)
# INFO:tensorflow:global_step/sec: 81.6869
# INFO:tensorflow:step = 17045, loss = 1.5197699 (1.225 sec)
# INFO:tensorflow:global_step/sec: 81.1689
# INFO:tensorflow:step = 17145, loss = 1.409203 (1.231 sec)
# INFO:tensorflow:global_step/sec: 81.8181
# INFO:tensorflow:step = 17245, loss = 1.3107219 (1.222 sec)
# INFO:tensorflow:global_step/sec: 80.4361
# INFO:tensorflow:step = 17345, loss = 1.2968777 (1.243 sec)
# INFO:tensorflow:global_step/sec: 81.1112
# INFO:tensorflow:step = 17445, loss = 1.2187794 (1.233 sec)
# INFO:tensorflow:global_step/sec: 81.9715
# INFO:tensorflow:step = 17545, loss = 1.2817307 (1.220 sec)
# INFO:tensorflow:global_step/sec: 81.5352
# INFO:tensorflow:step = 17645, loss = 1.4791752 (1.226 sec)
# INFO:tensorflow:global_step/sec: 81.087
# INFO:tensorflow:step = 17745, loss = 1.3424056 (1.233 sec)
# INFO:tensorflow:global_step/sec: 80.1856
# INFO:tensorflow:step = 17845, loss = 1.3783255 (1.247 sec)
# INFO:tensorflow:global_step/sec: 81.4058
# INFO:tensorflow:step = 17945, loss = 1.3656536 (1.229 sec)
# INFO:tensorflow:global_step/sec: 81.6991
# INFO:tensorflow:step = 18045, loss = 1.5627255 (1.224 sec)
# INFO:tensorflow:global_step/sec: 81.7342
# INFO:tensorflow:step = 18145, loss = 1.5201924 (1.229 sec)
# INFO:tensorflow:global_step/sec: 80.1764
# INFO:tensorflow:step = 18245, loss = 1.2913874 (1.241 sec)
# INFO:tensorflow:Saving checkpoints for 18330 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.4869359.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-16-02:46:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt-18330
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-16-02:46:11
# INFO:tensorflow:Saving dict for global step 18330: accuracy = 0.5735, global_step = 18330, loss = 1.1839807
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt-18330
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 18331 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:step = 18330, loss = 1.4983792
# INFO:tensorflow:global_step/sec: 71.8175
# INFO:tensorflow:step = 18430, loss = 1.255085 (1.394 sec)
# INFO:tensorflow:global_step/sec: 81.1557
# INFO:tensorflow:step = 18530, loss = 1.1055149 (1.233 sec)
# INFO:tensorflow:global_step/sec: 81.4253
# INFO:tensorflow:step = 18630, loss = 1.577944 (1.228 sec)
# INFO:tensorflow:global_step/sec: 80.0982
# INFO:tensorflow:step = 18730, loss = 1.3486018 (1.249 sec)
# INFO:tensorflow:global_step/sec: 81.2215
# INFO:tensorflow:step = 18830, loss = 1.4681836 (1.231 sec)
# INFO:tensorflow:global_step/sec: 81.3705
# INFO:tensorflow:step = 18930, loss = 1.1737785 (1.229 sec)
# INFO:tensorflow:global_step/sec: 80.7748
# INFO:tensorflow:step = 19030, loss = 1.5655514 (1.239 sec)
# INFO:tensorflow:global_step/sec: 81.039
# INFO:tensorflow:step = 19130, loss = 1.2078083 (1.238 sec)
# INFO:tensorflow:global_step/sec: 81.8308
# INFO:tensorflow:step = 19230, loss = 1.3933142 (1.217 sec)
# INFO:tensorflow:global_step/sec: 81.7227
# INFO:tensorflow:step = 19330, loss = 1.3716222 (1.224 sec)
# INFO:tensorflow:global_step/sec: 79.8549
# INFO:tensorflow:step = 19430, loss = 1.3375351 (1.252 sec)
# INFO:tensorflow:global_step/sec: 81.2054
# INFO:tensorflow:step = 19530, loss = 1.4108515 (1.231 sec)
# INFO:tensorflow:global_step/sec: 81.201
# INFO:tensorflow:step = 19630, loss = 1.2792485 (1.231 sec)
# INFO:tensorflow:global_step/sec: 80.4491
# INFO:tensorflow:step = 19730, loss = 1.3130989 (1.243 sec)
# INFO:tensorflow:global_step/sec: 81.8156
# INFO:tensorflow:step = 19830, loss = 1.4088109 (1.223 sec)
# INFO:tensorflow:global_step/sec: 81.254
# INFO:tensorflow:step = 19930, loss = 1.3678769 (1.231 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.2455342.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-16-02:46:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense1024_drop0.2_lr0.001_20180716024201/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-07-16-02:46:38
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.594, global_step = 20000, loss = 1.1454046
