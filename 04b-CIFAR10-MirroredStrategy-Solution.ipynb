# %%
import tensorflow as tf
import time
import os
import numpy as np

# %%
# Convolution Block

def _conv(x,kernel,name,log=False):
    with tf.variable_scope(name):
        W = tf.get_variable(initializer=tf.truncated_normal(shape=kernel,stddev=0.01),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[kernel[3]]),name='b')
        conv = tf.nn.conv2d(x, W, strides=[1,1,1,1],padding='SAME')
        activation = tf.nn.relu(tf.add(conv,b))
        pool = tf.nn.max_pool(activation,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')
        if log==True:
            tf.summary.histogram("weights",W)
            tf.summary.histogram("biases",b)
            tf.summary.histogram("activations",activation)
        return pool

# Dense Block

def _dense(x,size_in,size_out,name,relu=False,log=False):
    with tf.variable_scope(name):
        flat = tf.reshape(x,[-1,size_in])
        W = tf.get_variable(initializer=tf.truncated_normal([size_in,size_out],stddev=0.1),name='W')
        b = tf.get_variable(initializer=tf.constant(0.0,shape=[size_out]),name='b')
        activation = tf.add(tf.matmul(flat,W),b)
        if relu==True:
            activation = tf.nn.relu(activation)
        if log==True:
            tf.summary.histogram("weights",W)
            tf.summary.histogram("biases",b)
            tf.summary.histogram("activations",activation)
        return activation

# %%
def cnnmodel_fn(features, labels, mode, params):
    
    #### 1 INFERNCE MODEL
    
    input_layer = tf.reshape(features, [-1, 32, 32, 3])
    conv1 = _conv(input_layer,kernel=[5,5,3,128],name='conv1',log=params['log'])
    conv2 = _conv(conv1,kernel=[5,5,128,128],name='conv2',log=params['log'])
    conv3 = _conv(conv2,kernel=[3,3,128,256],name='conv3',log=params['log'])
    conv4 = _conv(conv3,kernel=[3,3,256,512],name='conv4',log=params['log'])
    dense = _dense(conv4,size_in=2*2*512,size_out=params['dense_units'],
                   name='Dense',relu=True,log=params['log'])
    if mode==tf.estimator.ModeKeys.TRAIN:
        dense = tf.nn.dropout(dense,params['drop_out'])
    logits = _dense(dense,size_in=params['dense_units'],
                    size_out=10,name='Output',relu=False,log=params['log'])
        
    #### 2 CALCULATIONS AND METRICS
    
    predictions = {"classes": tf.argmax(input=logits,axis=1),
                   "logits": logits,
                   "probabilities": tf.nn.softmax(logits,name='softmax')}
    export_outputs = {'predictions': tf.estimator.export.PredictOutput(predictions)}
    if (mode==tf.estimator.ModeKeys.TRAIN or mode==tf.estimator.ModeKeys.EVAL):
        loss = tf.losses.sparse_softmax_cross_entropy(labels=labels,logits=logits)
        #accuracy = tf.metrics.accuracy(
        #    labels=labels, predictions=tf.argmax(logits,axis=1))
        #metrics = {'accuracy':accuracy}
        
    #### 3 MODE = PREDICT
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(
            mode=mode, predictions=predictions, export_outputs=export_outputs)

    #### 4 MODE = TRAIN

    if mode == tf.estimator.ModeKeys.TRAIN:
        learning_rate = tf.train.exponential_decay(
            params['learning_rate'],tf.train.get_global_step(),
            decay_steps=100000,decay_rate=0.96)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
        if params['replicate']==True:
            optimizer = tf.contrib.estimator.TowerOptimizer(optimizer)
        train_op = optimizer.minimize(loss=loss,global_step=tf.train.get_global_step())
        tf.summary.scalar('learning_rate', learning_rate)
        #tf.summary.scalar('accuracy',accuracy[1])
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss, train_op=train_op)
    
    #### 5 MODE = EVAL
    
    if mode == tf.estimator.ModeKeys.EVAL:
        accuracy = tf.metrics.accuracy(
            labels=labels, predictions=tf.argmax(logits,axis=1))
        metrics = {'accuracy':accuracy}
        return tf.estimator.EstimatorSpec(
            mode=mode,loss=loss,eval_metric_ops=metrics)
            #mode=mode,loss=loss) #,eval_metric_ops=metrics)

# %%
def parse_tfrecord(example):
    feature={'idx'     : tf.FixedLenFeature((), tf.int64),
             'label'   : tf.FixedLenFeature((), tf.int64),
             'image'   : tf.FixedLenFeature((), tf.string, default_value="")}
    parsed = tf.parse_single_example(example, feature)
    image = tf.decode_raw(parsed['image'],tf.float64)
    image = tf.cast(image,tf.float32)
    image = tf.reshape(image,[32,32,3])
    return image, parsed['label']

# %%
def image_scaling(x):
    return tf.image.per_image_standardization(x)

def distort(x):
    x = tf.image.resize_image_with_crop_or_pad(x, 40, 40)
    x = tf.random_crop(x, [32, 32, 3])
    x = tf.image.random_flip_left_right(x)
    return x

# %%
def dataset_input_fn(params):
    dataset = tf.data.TFRecordDataset(
        params['filenames'],num_parallel_reads=params['threads'])
    dataset = dataset.map(parse_tfrecord, num_parallel_calls=params['threads'])
    dataset = dataset.map(lambda x,y: (image_scaling(x),y),num_parallel_calls=params['threads'])
    if params['mode']==tf.estimator.ModeKeys.TRAIN:
        dataset = dataset.map(lambda x,y: (distort(x),y),num_parallel_calls=params['threads'])
        dataset = dataset.shuffle(buffer_size=params['shuffle_buff'])
    dataset = dataset.repeat()
    dataset = dataset.batch(params['batch'])
    dataset = dataset.prefetch(2*params['batch'])
    return dataset

# %%
model_params  = {'drop_out'      : 0.2,
                 'dense_units'   : 1024,
                 'learning_rate' : 1e-3,
                 'log'           : True,
                 'replicate'     : False
                }

# %%
distribution = tf.contrib.distribute.MirroredStrategy(num_gpus=4)
config = tf.estimator.RunConfig(save_checkpoints_secs = 30,
                                keep_checkpoint_max = 5,
                                session_config=tf.ConfigProto(
                                    allow_soft_placement=True, log_device_placement=True),
                                train_distribute = distribution)
'''
config = tf.estimator.RunConfig(save_checkpoints_secs = 300,keep_checkpoint_max = 5)
'''
# Out:
# '\nconfig = tf.estimator.RunConfig(save_checkpoints_secs = 300,keep_checkpoint_max = 5)\n'

# %%
if model_params['replicate']==True:
    model_fn = tf.contrib.estimator.replicate_model_fn(
        cnnmodel_fn, loss_reduction=tf.losses.Reduction.MEAN)
else:
    model_fn = cnnmodel_fn

# %%
name = 'cnn_model/cnn_model_'
if model_params['replicate']==True:
    name = 'cnn_model_dist/cnn_model_'
name = name + 'dense(' + str(model_params['dense_units']) + ')_'
name = name + 'drop(' + str(model_params['drop_out']) + ')_'
name = name + 'lr(' + str(model_params['learning_rate']) + ')_'
name = name + time.strftime("%Y%m%d%H%M%S")
model_dir  = os.path.join('./',name)

print(model_dir)
# Out:
# ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424

# %%
model_dir='./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424'
model_dir
# Out:
# './cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424'

# %%
estimator = tf.estimator.Estimator(
    model_fn=model_fn,model_dir=model_dir,params=model_params,config=config)
# Out:
# INFO:tensorflow:Using config: {'_service': None, '_save_summary_steps': 100, '_task_id': 0, '_model_dir': './cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424', '_save_checkpoints_secs': 30, '_session_config': allow_soft_placement: true
# log_device_placement: true
# , '_log_step_count_steps': 100, '_global_id_in_cluster': 0, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None, '_master': '', '_train_distribute': <tensorflow.contrib.distribute.python.mirrored_strategy.MirroredStrategy object at 0x7fc5889efba8>, '_keep_checkpoint_max': 5, '_num_worker_replicas': 1, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc5889efe80>, '_task_type': 'worker', '_save_checkpoints_steps': None, '_evaluation_master': '', '_num_ps_replicas': 0}

# %%
#train_files = 'gs://tsaikevin-data/cifar10/train.tfrecords'
#val_files   = 'gs://tsaikevin-data/cifar10/validation.tfrecords'
train_files = !ls cifar10_data_00*.tfrecords
val_files   = !ls cifar10_data_01*.tfrecords

train_params = {'filenames'    : train_files,
                'mode'         : tf.estimator.ModeKeys.TRAIN,
                'threads'      : 16,
                'shuffle_buff' : 100000,
                'batch'        : 100
               }

eval_params  = {'filenames'    : val_files,
                'mode'         : tf.estimator.ModeKeys.EVAL,
                'threads'      : 8,
                'batch'        : 200
               }

train_spec = tf.estimator.TrainSpec(input_fn=lambda: dataset_input_fn(train_params),max_steps=200000)
eval_spec  = tf.estimator.EvalSpec(input_fn=lambda: dataset_input_fn(eval_params),steps=10,throttle_secs=60)

# %%
tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 60 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:CPU:0
# INFO:tensorflow:Configured nccl all-reduce.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:batch_all_reduce invoked for batches size = 12 with algorithm = nccl and num_packs = 1
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:loss = 2.3023107, step = 0
# INFO:tensorflow:global_step/sec: 30.1916
# INFO:tensorflow:loss = 2.2990088, step = 100 (3.315 sec)
# INFO:tensorflow:global_step/sec: 22.5528
# INFO:tensorflow:loss = 2.2990944, step = 200 (4.434 sec)
# INFO:tensorflow:global_step/sec: 22.5529
# INFO:tensorflow:loss = 2.2921624, step = 300 (4.437 sec)
# INFO:tensorflow:global_step/sec: 23.2705
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-05-29-04:25:29
# INFO:tensorflow:Saving dict for global step 12415: accuracy = 0.5325, global_step = 12415, loss = 1.3263123
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:batch_all_reduce invoked for batches size = 12 with algorithm = nccl and num_packs = 1
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-12415
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 12416 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:loss = 1.5092213, step = 12415
# INFO:tensorflow:global_step/sec: 29.9039
# INFO:tensorflow:loss = 1.4924756, step = 12515 (3.346 sec)
# INFO:tensorflow:global_step/sec: 23.4418
# INFO:tensorflow:loss = 1.4969249, step = 12615 (4.265 sec)
# INFO:tensorflow:global_step/sec: 22.8561
# INFO:tensorflow:loss = 1.5722301, step = 12715 (4.376 sec)
# INFO:tensorflow:global_step/sec: 23.5011
# INFO:tensorflow:loss = 1.4669495, step = 12815 (4.255 sec)
# INFO:tensorflow:global_step/sec: 20.6397
# INFO:tensorflow:loss = 1.4566132, step = 12915 (4.845 sec)
# INFO:tensorflow:global_step/sec: 20.9429
# INFO:tensorflow:loss = 1.544609, step = 13015 (4.775 sec)
# INFO:tensorflow:Saving checkpoints for 13097 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:global_step/sec: 20.0564
# INFO:tensorflow:loss = 1.4575052, step = 13115 (4.986 sec)
# INFO:tensorflow:global_step/sec: 20.6281
# INFO:tensorflow:loss = 1.5778039, step = 13215 (4.848 sec)
# INFO:tensorflow:global_step/sec: 36.1866
# INFO:tensorflow:loss = 1.5062854, step = 13315 (2.765 sec)
# INFO:tensorflow:global_step/sec: 22.794
# INFO:tensorflow:loss = 1.4875697, step = 13415 (4.386 sec)
# INFO:tensorflow:global_step/sec: 22.8809
# INFO:tensorflow:loss = 1.434369, step = 13515 (4.371 sec)
# INFO:tensorflow:global_step/sec: 22.5023
# INFO:tensorflow:loss = 1.5354449, step = 13615 (4.446 sec)
# INFO:tensorflow:Saving checkpoints for 13666 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.4583497.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-29-04:26:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-13666
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-05-29-04:26:32
# INFO:tensorflow:Saving dict for global step 13666: accuracy = 0.5435, global_step = 13666, loss = 1.2852008
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:batch_all_reduce invoked for batches size = 12 with algorithm = nccl and num_packs = 1
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-14917
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 14918 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:loss = 1.3631516, step = 14917
# INFO:tensorflow:global_step/sec: 30.1243
# INFO:tensorflow:loss = 1.4351468, step = 15017 (3.323 sec)
# INFO:tensorflow:global_step/sec: 23.2182
# INFO:tensorflow:loss = 1.479563, step = 15117 (4.307 sec)
# INFO:tensorflow:global_step/sec: 22.5465
# INFO:tensorflow:loss = 1.4269197, step = 15217 (4.435 sec)
# INFO:tensorflow:global_step/sec: 23.4146
# INFO:tensorflow:loss = 1.4506156, step = 15317 (4.270 sec)
# INFO:tensorflow:global_step/sec: 20.2418
# INFO:tensorflow:loss = 1.4032973, step = 15417 (4.940 sec)
# INFO:tensorflow:global_step/sec: 20.487
# INFO:tensorflow:loss = 1.3909471, step = 15517 (4.882 sec)
# INFO:tensorflow:Saving checkpoints for 15599 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:global_step/sec: 19.751
# INFO:tensorflow:loss = 1.4832087, step = 15617 (5.063 sec)
# INFO:tensorflow:global_step/sec: 20.557
# INFO:tensorflow:loss = 1.4168264, step = 15717 (4.865 sec)
# INFO:tensorflow:global_step/sec: 36.0852
# INFO:tensorflow:loss = 1.3502631, step = 15817 (2.772 sec)
# INFO:tensorflow:global_step/sec: 22.3633
# INFO:tensorflow:loss = 1.4146018, step = 15917 (4.472 sec)
# INFO:tensorflow:global_step/sec: 22.1047
# INFO:tensorflow:loss = 1.4670631, step = 16017 (4.524 sec)
# INFO:tensorflow:global_step/sec: 22.3692
# INFO:tensorflow:loss = 1.3867334, step = 16117 (4.471 sec)
# INFO:tensorflow:Saving checkpoints for 16168 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.3759125.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-29-04:28:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-16168
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-05-29-04:28:39
# INFO:tensorflow:Saving dict for global step 16168: accuracy = 0.5785, global_step = 16168, loss = 1.2003843
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:batch_all_reduce invoked for batches size = 12 with algorithm = nccl and num_packs = 1
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-16168
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 16169 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:loss = 1.3570276, step = 16168
# INFO:tensorflow:global_step/sec: 29.8501
# INFO:tensorflow:loss = 1.4016532, step = 16268 (3.356 sec)
# INFO:tensorflow:global_step/sec: 23.3875
# INFO:tensorflow:loss = 1.3654928, step = 16368 (4.273 sec)
# INFO:tensorflow:global_step/sec: 22.7102
# INFO:tensorflow:loss = 1.3607672, step = 16468 (4.403 sec)
# INFO:tensorflow:global_step/sec: 23.5116
# INFO:tensorflow:loss = 1.436742, step = 16568 (4.252 sec)
# INFO:tensorflow:global_step/sec: 20.7583
# INFO:tensorflow:loss = 1.3965397, step = 16668 (4.817 sec)
# INFO:tensorflow:global_step/sec: 20.769
# INFO:tensorflow:loss = 1.4142356, step = 16768 (4.815 sec)
# INFO:tensorflow:Saving checkpoints for 16850 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:global_step/sec: 19.8194
# INFO:tensorflow:loss = 1.281502, step = 16868 (5.045 sec)
# INFO:tensorflow:global_step/sec: 20.8969
# INFO:tensorflow:loss = 1.4130588, step = 16968 (4.786 sec)
# INFO:tensorflow:global_step/sec: 35.9735
# INFO:tensorflow:loss = 1.3392015, step = 17068 (2.781 sec)
# INFO:tensorflow:global_step/sec: 22.9983
# INFO:tensorflow:loss = 1.2810605, step = 17168 (4.348 sec)
# INFO:tensorflow:global_step/sec: 22.8998
# INFO:tensorflow:loss = 1.2744101, step = 17268 (4.367 sec)
# INFO:tensorflow:global_step/sec: 22.3202
# INFO:tensorflow:loss = 1.3177254, step = 17368 (4.483 sec)
# INFO:tensorflow:Saving checkpoints for 17419 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.4050915.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-29-04:29:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-17419
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-05-29-04:29:43
# INFO:tensorflow:Saving dict for global step 17419: accuracy = 0.585, global_step = 17419, loss = 1.1726916
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:batch_all_reduce invoked for batches size = 12 with algorithm = nccl and num_packs = 1
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-17419
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 17420 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:loss = 1.3134482, step = 17419
# INFO:tensorflow:global_step/sec: 30.0162
# INFO:tensorflow:loss = 1.4714502, step = 17519 (3.334 sec)
# INFO:tensorflow:global_step/sec: 23.4925
# INFO:tensorflow:loss = 1.4622798, step = 17619 (4.257 sec)
# INFO:tensorflow:global_step/sec: 22.8259
# INFO:tensorflow:loss = 1.2953876, step = 17719 (4.381 sec)
# INFO:tensorflow:global_step/sec: 23.136
# INFO:tensorflow:loss = 1.3660716, step = 17819 (4.321 sec)
# INFO:tensorflow:global_step/sec: 19.9073
# INFO:tensorflow:loss = 1.4335877, step = 17919 (5.024 sec)
# INFO:tensorflow:global_step/sec: 20.456
# INFO:tensorflow:loss = 1.2787898, step = 18019 (4.888 sec)
# INFO:tensorflow:Saving checkpoints for 18101 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:global_step/sec: 19.8875
# INFO:tensorflow:loss = 1.3185924, step = 18119 (5.028 sec)
# INFO:tensorflow:global_step/sec: 20.6847
# INFO:tensorflow:loss = 1.3106643, step = 18219 (4.835 sec)
# INFO:tensorflow:global_step/sec: 35.8907
# INFO:tensorflow:loss = 1.3831332, step = 18319 (2.787 sec)
# INFO:tensorflow:global_step/sec: 22.8674
# INFO:tensorflow:loss = 1.3349279, step = 18419 (4.373 sec)
# INFO:tensorflow:global_step/sec: 22.1411
# INFO:tensorflow:loss = 1.3160393, step = 18519 (4.516 sec)
# INFO:tensorflow:global_step/sec: 22.6383
# INFO:tensorflow:loss = 1.4906169, step = 18619 (4.420 sec)
# INFO:tensorflow:Saving checkpoints for 18670 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.2827089.
# INFO:tensorflow:Calling model_fn.
# ...
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-194736
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-05-29-06:56:44
# INFO:tensorflow:Saving dict for global step 194736: accuracy = 0.849, global_step = 194736, loss = 0.44493112
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:batch_all_reduce invoked for batches size = 12 with algorithm = nccl and num_packs = 1
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-194736
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for
# INFO:tensorflow:Saving checkpoints for 199275 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:global_step/sec: 20.2935
# INFO:tensorflow:loss = 0.27789533, step = 199280 (4.928 sec)
# INFO:tensorflow:global_step/sec: 21.2648
# INFO:tensorflow:loss = 0.29187804, step = 199380 (4.702 sec)
# INFO:tensorflow:global_step/sec: 36.7127
# INFO:tensorflow:loss = 0.3136226, step = 199480 (2.725 sec)
# INFO:tensorflow:global_step/sec: 23.0157
# INFO:tensorflow:loss = 0.31454328, step = 199580 (4.345 sec)
# INFO:tensorflow:global_step/sec: 22.5237
# INFO:tensorflow:loss = 0.33216405, step = 199680 (4.439 sec)
# INFO:tensorflow:global_step/sec: 22.8979
# INFO:tensorflow:loss = 0.39376587, step = 199780 (4.368 sec)
# INFO:tensorflow:Saving checkpoints for 199862 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.297916.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-29-07:00:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-199862
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-05-29-07:00:56
# INFO:tensorflow:Saving dict for global step 199862: accuracy = 0.86, global_step = 199862, loss = 0.4174586
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:batch_all_reduce invoked for batches size = 12 with algorithm = nccl and num_packs = 1
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-199862
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 199863 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:loss = 0.31069583, step = 199862
# INFO:tensorflow:global_step/sec: 30.448
# INFO:tensorflow:loss = 0.36835158, step = 199962 (3.290 sec)
# INFO:tensorflow:Saving checkpoints for 200000 into ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.35120246.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-29-07:01:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./cnn_model/cnn_model_dense(1024)_drop(0.2)_lr(0.001)_20180529041424/model.ckpt-200000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2018-05-29-07:01:09
# INFO:tensorflow:Saving dict for global step 200000: accuracy = 0.855, global_step = 200000, loss = 0.44200024
